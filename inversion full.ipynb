# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
from pygimli.physics import ert

# %% [markdown]
# # November 25 ERT 1

# %%
data1 = ert.load('Surveys/full_data/nov25_1_pygimli copy.dat')
print(data1)
# Out:
# Data: Sensors: 55 data: 586, nonzero entries: ['a', 'b', 'm', 'n', 'r', 'valid']
# Warning: removed 85 values due to sensor index out of bounds!
# Data validity check: found 85 invalid data.
# Data validity check: remove invalid data.

# %%
data1["k"] = ert.geometricFactors(data1)

# %%
data1["rhoa"] = data1("r") * data1("k")

# %%
ax, cb = ert.show(data1)
# Out:
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: divide by zero encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: invalid value encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:337: RuntimeWarning: invalid value encountered in subtract
#   ab, am, an = np.abs(a-b), np.abs(a-m), np.abs(a-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:338: RuntimeWarning: invalid value encountered in subtract
#   bm, bn, mn = np.abs(b-m), np.abs(b-n), np.abs(m-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:345: RuntimeWarning: invalid value encountered in subtract
#   sep = np.abs(a-m)  # * mI # does not make sense here
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:414: RuntimeWarning: invalid value encountered in multiply
#   mid *= de
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 28/01/24 - 20:24:18 - pyGIMLi - WARNING - Something gone wrong while drawing data. Try fallback with equidistant electrodes.

# %%
data1["err"] = ert.estimateError(data1, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data1, verbose=True,sr=False)

# %%
mgr.invert(verbose=True)
# Out:
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Found 2 regions.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Found 2 regions.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2110 Cells: 3932 Boundaries: 3092
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Use median(data values)=67.45197147358076
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Created startmodel from forward operator: 773 [67.45197147358076,...,67.45197147358076]
# 28/01/24 - 20:24:22 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  1
#
# Statistics:
#
#   Input vertices: 117
#   Input segments: 118
#   Input holes: 0
#
#   Mesh vertices: 564
#   Mesh triangles: 983
#   Mesh edges: 1546
#   Mesh exterior boundary edges: 143
#   Mesh interior boundary edges: 24
#   Mesh subsegments (constrained edges): 167
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1461.69 : 1472.52
# Found datafile: 55 electrodes
# Found: 55 node-electrodes
# rMin = 1.25854, rMax = 320.05
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.011997 s
# FOP updating mesh dependencies ... 3e-06 s
# min/max(dweight) = 3.23606/49.3036
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f5366022520>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f5363e5e1b0>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f5363e5ede0>
# min/max (data): 1.11/5135
# min/max (error): 2.03%/30.9%
# min/max (start model): 67.45/67.45
# --------------------------------------------------------------------------------
# Calculating response for model: min = 67.452 max = 67.452
# Forward: time: 0.335229s
# Response: min = 63.7457 max = 83.5307 mean = 68.7247
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 3.23606/49.3036
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1090 x 773
# check Jacobian: wrong dimensions: (0x0) should be (586x773)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0037847:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.7827s
# sens sum: median = 1.0499 min = 0.920017 max = 1.69831
# ... 0.784231 s
# min data = 1.11149 max data = 5135.45 (586)
# min error = 0.0202825 max error = 0.309017 (586)
# min response = 63.7457 max response = 83.5307 (586)
# calc without reference model
# 0: rms/rrms(data, response) = 432.007/382.972%
# 0: chi^2(data, response, error, log) = 2140.34
# 0: Phi = 1.25424e+06 + 0 * 20 = 1.25424e+06
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.466136 max = 51446.1
# Forward: time: 0.314321s
# Response: min = 2.64634 max = 240.406 mean = 43.8987
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 1: LS newModel: min = 0.466136; max = 51446.1
# 1: LS newResponse: min = 2.64634; max = 240.406
# 1: rms/rrms(data, LS newResponse) = 425.917/115.923%
# 1: chi^2(data, LS newResponse, error, log) = 2108.23
# 1: Phi = 1.23542e+06+598.98*20=1.2474e+06
# Linesearch tau = 0.5
# Calculating response for model: min = 5.6073 max = 1862.83
# Forward: time: 0.373316s
# Response: min = 14.0725 max = 191.911 mean = 70.4255
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 1147.71 (dPhi = 46.14%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 5.6073; max = 1862.83
# 1: Response: min = 14.0725; max = 191.911
# 1: rms/rrms(data, Response) = 411.776/222.522%
# 1: chi^2(data, Response, error, log) = 1147.71
# 1: Phi = 672556+149.745*20=675551
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004517:time: 0.732657s
# sens sum: median = 1.85788 min = 0.74936 max = 4.64587
# ... 0.734328 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.378217 max = 90343.5
# Forward: time: 0.325521s
# Response: min = 3.0023 max = 474.517 mean = 73.0766
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 2: LS newModel: min = 0.378217; max = 90343.5
# 2: LS newResponse: min = 3.0023; max = 474.517
# 2: rms/rrms(data, LS newResponse) = 391.56/145.072%
# 2: chi^2(data, LS newResponse, error, log) = 1151.19
# 2: Phi = chi² = 765.98 (dPhi = 32.67%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 674597+703.3*20=688663
# Linesearch tau = 0.47
# Calculating response for model: min = 1.859 max = 7804.17
# Forward: time: 0.334114s
# Response: min = 7.00391 max = 394.863 mean = 84.059
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 2: Model: min = 1.859; max = 7804.17
# 2: Response: min = 7.00391; max = 394.863
# 2: rms/rrms(data, Response) = 388.084/200.351%
# 2: chi^2(data, Response, error, log) = 765.981
# 2: Phi = 448865+298.872*20=454842
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004296:time: 0.744402s
# sens sum: median = 3.22691 min = 0.519034 max = 17.5137
# ... 0.746166 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.021766 max = 123102
# Forward: time: 0.341003s
# Response: min = 4.19901 max = 773.923 mean = 92.8926
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 3: LS newModel: min = 0.021766; max = 123102
# 3: LS newResponse: min = 4.19901; max = 773.923
# 3: rms/rrms(data, LS newResponse) = 388.797/202.648%
# 3: chi^2(data, LS newResponse, error, log) = 971.918
# 3: Phi = 569544+966.469*20=588873
# Linesearch tau = 0.13
# Calculating response for model: min = 1.98671 max = 8649.79
# Forward: time: 0.355868s
# Response: min = 6.70035 max = 485.596 mean = 92.01
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 657.13 (dPhi = 13.89%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 1.98671; max = 8649.79
# 3: Response: min = 6.70035; max = 485.596
# 3: rms/rrms(data, Response) = 377.694/211.925%
# 3: chi^2(data, Response, error, log) = 657.135
# 3: Phi = 385081+329.421*20=391669
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004888:time: 0.771159s
# sens sum: median = 3.50516 min = 0.450498 max = 20.885
# ... 0.772607 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.000637842 max = 168888
# Forward: time: 0.314823s
# Response: min = 4.47065 max = 725.827 mean = 95.3354
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 4: LS newModel: min = 0.000637842; max = 168888
# 4: LS newResponse: min = 4.47065; max = 725.827
# 4: rms/rrms(data, LS newResponse) = 368.256/278.619%
# 4: chi^2(data, LS newResponse, error, log) = 631.369
# 4: Phi = chi² = 460.66 (dPhi = 27.97%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... 369982+1105.22*20=392086
# Linesearch tau = 0.5
# Calculating response for model: min = 0.0431708 max = 26975.1
# Forward: time: 0.314328s
# Response: min = 5.8709 max = 750.817 mean = 111.17
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 4: Model: min = 0.0431708; max = 26975.1
# 4: Response: min = 5.8709; max = 750.817
# 4: rms/rrms(data, Response) = 349.48/262.709%
# 4: chi^2(data, Response, error, log) = 460.655
# 4: Phi = 269944+608.183*20=282108
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004432:time: 0.816424s
# sens sum: median = 2.06969 min = -306.011 max = 40.6719
# ... 0.817819 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.000279791 max = 19036.3
# Forward: time: 0.324971s
# Response: min = 8.67202 max = 1172.05 mean = 136.506
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 5: LS newModel: min = 0.000279791; max = 19036.3
# 5: LS newResponse: min = 8.67202; max = 1172.05
# 5: rms/rrms(data, LS newResponse) = 330.316/226.064%
# 5: chi^2(data, LS newResponse, error, log) = 486.593
# 5: Phi = 285144+1099.72*20=307138
# Linesearch tau = 0.35
# Calculating response for model: min = 0.00746716 max = 15422.5
# chi² = 360.44 (dPhi = 20.18%) lam: 20.0Forward: time: 0.348091s
# Response: min = 6.17098 max = 1066.77 mean = 132.399
# Reciprocity rms(modelReciprocity) 3.13784e-09%, max: 7.5959e-08%
# 5: Model: min = 0.00746716; max = 15422.5
# 5: Response: min = 6.17098; max = 1066.77
# 5: rms/rrms(data, Response) = 325.427/264.795%
# 5: chi^2(data, Response, error, log) = 360.436
# 5: Phi = 211215+697.9*20=225173
#
# --------------------------------------------------------------------------------
# inv.iter 6 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004349:time: 0.732785s
# sens sum: median = -10.5276 min = -1625.91 max = 103.684
# ... 0.734355 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 6.75417e-05 max = 145320
# Forward: time: 0.365489s
# Response: min = 8.01886 max = 1032.25 mean = 146.575
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 6: LS newModel: min = 6.75417e-05; max = 145320
# 6: LS newResponse: min = 8.01886; max = 1032.25
# 6: rms/rrms(data, LS newResponse) = 321.893/370.051%
# 6: chi^2(data, LS newResponse, error, log) = 336.484
# 6: Phi = 197180+1084.68*20=218873
# Linesearch tau = 0.6
# Calculating response for model: min = 0.00151272 max = 57697.6
# Forward: time: 0.376779s
# Response: min = 7.49646 max = 1361.02 mean = 153.426
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 298.28 (dPhi = 14.56%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... 6: Model: min = 0.00151272; max = 57697.6
# 6: Response: min = 7.49646; max = 1361.02
# 6: rms/rrms(data, Response) = 305.872/343.324%
# 6: chi^2(data, Response, error, log) = 298.283
# 6: Phi = 174794+879.53*20=192384
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0005128:time: 0.812855s
# sens sum: median = -24.3922 min = -3042.79 max = 212.427
# ... 0.81418 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.3847e-06 max = 8425.6
# Forward: time: 0.310178s
# Response: min = 3.31635 max = 746.233 mean = 87.0491
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3chi² = 288.99 (dPhi = 3.15%) lam: 20.0Calculating response for model: min = 0.00237598 max = 21684
# Forward: time: 0.309843s
# Response: min = 7.95715 max = 1239.65 mean = 151.391
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.151476
# 7: LS newModel: min = 3.3847e-06; max = 8425.6
# 7: LS newResponse: min = 3.31635; max = 746.233
# 7: rms/rrms(data, LS newResponse) = 388.846/180.145%
# 7: chi^2(data, LS newResponse, error, log) = 803.346
# 7: Phi = 470761+1012.09*20=491002
# Linesearch tau = 0.151476
# Calculating response for model: min = 0.00692076 max = 35201.2
# Forward: time: 0.314852s
# Response: min = 7.41508 max = 1410.89 mean = 157.066
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 7: Model: min = 0.00692076; max = 35201.2
# 7: Response: min = 7.41508; max = 1410.89
# 7: rms/rrms(data, Response) = 302.582/330.861%
# 7: chi^2(data, Response, error, log) = 288.994
# 7: Phi = 169350+848.583*20=186322
#
# --------------------------------------------------------------------------------
# inv.iter 8 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0007668:time: 0.701017s
# sens sum: median = -40.4627 min = -4493.61 max = 289.246
# ... 0.702501 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.000130014 max = 21683.9
# Forward: time: 0.329193s
# Response: min = 7.44795 max = 1401.85 mean = 157.368
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.00263047 max = 29943.2
# Forward: time: 0.310254s
# Response: min = 7.314 max = 1526.61 mean = 162.737
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 276.84 (dPhi = 3.14%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 9 ...  ==> tau = 0.397675
# 8: LS newModel: min = 0.000130014; max = 21683.9
# 8: LS newResponse: min = 7.44795; max = 1401.85
# 8: rms/rrms(data, LS newResponse) = 304.96/259.026%
# 8: chi^2(data, LS newResponse, error, log) = 294.469
# 8: Phi = 172559+1073.65*20=194032
# Linesearch tau = 0.397675
# Calculating response for model: min = 0.00172899 max = 28406.9
# Forward: time: 0.323187s
# Response: min = 7.45213 max = 1539.4 mean = 163.432
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 8: Model: min = 0.00172899; max = 28406.9
# 8: Response: min = 7.45213; max = 1539.4
# 8: rms/rrms(data, Response) = 296.546/306.916%
# 8: chi^2(data, Response, error, log) = 276.844
# 8: Phi = 162231+912.025*20=180471
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0006207:time: 0.718025s
# sens sum: median = -43.4896 min = -5552.1 max = 318.415
# ... 0.719293 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 4.67466e-05 max = 33277.1
# Forward: time: 0.331s
# Response: min = 6.30553 max = 891.875 mean = 125.502
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.00283413 max = 29037
# chi² = 270.87 (dPhi = 1.95%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.95 (< 2.0%)                 #
# ################################################################################
# Forward: time: 0.306526s
# Response: min = 7.7471 max = 1598.9 mean = 167.132
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.168056
# 9: LS newModel: min = 4.67466e-05; max = 33277.1
# 9: LS newResponse: min = 6.30553; max = 891.875
# 9: rms/rrms(data, LS newResponse) = 364.985/347.897%
# 9: chi^2(data, LS newResponse, error, log) = 570.178
# 9: Phi = 334124+1026.86*20=354661
# Linesearch tau = 0.168056
# Calculating response for model: min = 0.00614384 max = 28758.2
# Forward: time: 0.315864s
# Response: min = 7.48004 max = 1635.01 mean = 167.927
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 9: Model: min = 0.00614384; max = 28758.2
# 9: Response: min = 7.48004; max = 1635.01
# 9: rms/rrms(data, Response) = 292.575/320.74%
# 9: chi^2(data, Response, error, log) = 270.87
# 9: Phi = 158730+911.084*20=176952
# 773 [19.08983540861911,...,23419.77266809029]

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0.1, cMax=5000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([1450, ax.get_ylim()[1]])
# Out:
# (1450.0, 1490.006104)

# %% [markdown]
# ## ...

# %% [markdown]
# # November 25 ERT 2

# %%
data2 = ert.load('Surveys/full_data/nov25_2_pygimli copy.dat')
print(data2)
# Out:
# Data: Sensors: 32 data: 327, nonzero entries: ['a', 'b', 'm', 'n', 'r', 'valid']

# %%
data2["k"] = ert.geometricFactors(data2)

# %%
data2["rhoa"] = data2("r") * data2("k")

# %%
data2["err"] = ert.estimateError(data2, relativeError=0.02, absoluteUError=50e-6)

# %%
ax, cb = ert.show(data2)

# %%
mgr2 = ert.ERTManager(data2, verbose=True)
mgr2.invert(verbose=True)
# Out:
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Found 2 regions.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Found 2 regions.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1325 Cells: 2456 Boundaries: 1938
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Use median(data values)=178.33116147876015
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Created startmodel from forward operator: 451 [178.33116147876015,...,178.33116147876015]
# 28/01/24 - 20:39:52 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 71
#   Input segments: 72
#   Input holes: 0
#
#   Mesh vertices: 356
#   Mesh triangles: 614
#   Mesh edges: 969
#   Mesh exterior boundary edges: 96
#   Mesh interior boundary edges: 16
#   Mesh subsegments (constrained edges): 112
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0067432 s
# FOP updating mesh dependencies ... 2e-06 s
# min/max(dweight) = 3.27103/49.8679
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f5362160090>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f5362a46570>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f53626d7060>
# min/max (data): 3.51/765
# min/max (error): 2.01%/30.57%
# min/max (start model): 178/178
# --------------------------------------------------------------------------------
# Calculating response for model: min = 178.331 max = 178.331
# Allocating memory for primary potential...... 0.0032209
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 5105	Cells: 2456	Boundaries: 3780
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0102391 s
# FOP updating mesh dependencies ... 2e-06 s
# Forward: time: 0.918865s
# Interpolating to secondary mesh
#
# 512 	/ 512
# Forward: time: 1.42785s
# Response: min = 168.693 max = 203.084 mean = 181.304
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 3.27103/49.8679
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 635 x 451
# check Jacobian: wrong dimensions: (0x0) should be (327x451)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0014769:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.211605s
# sens sum: median = 1.0505 min = 0.963536 max = 1.41265
# ... 0.212116 s
# min data = 3.51226 max data = 765.163 (327)
# min error = 0.020053 max error = 0.305714 (327)
# min response = 168.693 max response = 203.084 (327)
# calc without reference model
# 0: rms/rrms(data, response) = 104.362/313.249%
# 0: chi^2(data, response, error, log) = 168.119
# 0: Phi = 54975 + 0 * 20 = 54975
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 48.2515 max = 1097.4
# Using existing primary potentials.
# Forward: time: 0.151954s
# Response: min = 94.0923 max = 485.178 mean = 183.439
# Reciprocity rms(modelReciprocity) 6.11778%, max: 22.9303%
# 1: LS newModel: min = 48.2515; max = 1097.4
# 1: LS newResponse: min = 95.9579; max = 496.509
# 1: rms/rrms(data, LS newResponse) = 66.1471/236.643%
# 1: chi^2(data, LS newResponse, error, log) = 72.8202
# 1: Phi = 23812.2+59.9637*20=25011.5
# Linesearch tau = 0.86
# Calculating response for model: min = 57.9417 max = 850.914
# Using existing primary potentials.
# Forward: time: 0.161037s
# Response: min = 104.034 max = 431.222 mean = 184.133
# Reciprocity rms(modelReciprocity) 4.85973%, max: 17.2824%
# chi² = 66.08 (dPhi = 59.08%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 57.9417; max = 850.914
# 1: Response: min = 105.831; max = 439.916
# 1: rms/rrms(data, Response) = 69.2974/245.481%
# 1: chi^2(data, Response, error, log) = 66.0761
# 1: Phi = 21606.9+44.3492*20=22493.9
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0002263:time: 0.188844s
# chi² = 44.08 (dPhi = 30.96%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... sens sum: median = 1.18982 min = 0.944451 max = 1.91907
# ... 0.189497 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 69.2128 max = 1212.72
# Using existing primary potentials.
# Forward: time: 0.159545s
# Response: min = 103.701 max = 519.369 mean = 202.721
# Reciprocity rms(modelReciprocity) 5.35764%, max: 17.4169%
# Linesearch tau = 1
# 2: Model: min = 69.2128; max = 1212.72
# 2: Response: min = 104.849; max = 529.237
# 2: rms/rrms(data, Response) = 63.0581/259.794%
# 2: chi^2(data, Response, error, log) = 44.08
# 2: Phi = 14414.2+55.7629*20=15529.4
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0003459:time: 0.203264s
# sens sum: median = 1.22696 min = 0.813851 max = 2.17529
# ... 0.203783 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 68.9141 max = 1220.04
# Using existing primary potentials.
# Forward: time: 0.161486s
# Response: min = 104.302 max = 550.37 mean = 208.685
# Reciprocity rms(modelReciprocity) 5.68139%, max: 21.0669%
# chi² = 43.11 (dPhi = 1.93%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Linesearch tau = 1
# 3: Model: min = 68.9141; max = 1220.04
# 3: Response: min = 105.876; max = 561.101
# 3: rms/rrms(data, Response) = 63.9405/266.645%
# 3: chi^2(data, Response, error, log) = 43.1086
# 3: Phi = 14096.5+56.6451*20=15229.4
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001981:time: 0.242593s
# sens sum: median = 1.23972 min = 0.803703 max = 2.20988
# ... 0.243107 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 68.5004 max = 1237.12
# Using existing primary potentials.
# Forward: time: 0.163681s
# Response: min = 103.958 max = 553.615 mean = 209.193
# Reciprocity rms(modelReciprocity) 5.8341%, max: 21.8703%
# 4: LS newModel: min = 68.5004; max = 1237.12
# 4: LS newResponse: min = 105.717; max = 564.487
# 4: rms/rrms(data, LS newResponse) = 64.1212/266.778%
# 4: chi^2(data, LS newResponse, error, log) = 43.0216
# 4: Phi = 14068.1+57.7797*20=15223.7
# Linesearch tau = 0.91
# Calculating response for model: min = 68.5375 max = 1235.57
# chi² = 43.03 (dPhi = 0.04%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 0.04 (< 2.0%)                 #
# ################################################################################
# 451 [174.7972249342321,...,471.38885621678344]
# Using existing primary potentials.
# Forward: time: 0.163812s
# Response: min = 103.988 max = 553.339 mean = 209.149
# Reciprocity rms(modelReciprocity) 5.82027%, max: 21.7958%
# 4: Model: min = 68.5375; max = 1235.57
# 4: Response: min = 105.731; max = 564.199
# 4: rms/rrms(data, Response) = 64.1033/266.762%
# 4: chi^2(data, Response, error, log) = 43.0279
# 4: Phi = 14070.1+57.6709*20=15223.6

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=2000)
ax, cb = mgr2.showResult(**kw)
ax.grid(True)
ax.set_ylim([1540, ax.get_ylim()[1]])
# Out:
# (1540.0, 1575.122437)

# %% [markdown]
# # ...

# %% [markdown]
# # November 24 ERT 1

# %%
data3 = ert.load('Surveys/nov25_2_pygimli.dat')
print(data3)
# Out:
# Data: Sensors: 32 data: 327, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data3)

# %%
data3["k"] = ert.geometricFactors(data3)
data3["err"] = ert.estimateError(data3, relativeError=0.02, absoluteUError=50e-6)
mgr3 = ert.ERTManager(data3, verbose=True)
mgr3.invert(verbose=True)
# Out:
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1325 Cells: 2456 Boundaries: 1938
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Use median(data values)=190.12710571
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Created startmodel from forward operator: 451 [190.12710571,...,190.12710571]
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 71
#   Input segments: 72
#   Input holes: 0
#
#   Mesh vertices: 356
#   Mesh triangles: 614
#   Mesh edges: 969
#   Mesh exterior boundary edges: 96
#   Mesh interior boundary edges: 16
#   Mesh subsegments (constrained edges): 112
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0077392 s
# FOP updating mesh dependencies ... 2.9e-06 s
# min/max(dweight) = 29.0577/49.8991
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e98a91030>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e98af0c70>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7eb2c56070>
# min/max (data): 21.51/3017
# min/max (error): 2%/3.44%
# min/max (start model): 190/190
# --------------------------------------------------------------------------------
# Calculating response for model: min = 190.127 max = 190.127
# Allocating memory for primary potential...... 0.0006105
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 5105	Cells: 2456	Boundaries: 3780
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0109201 s
# FOP updating mesh dependencies ... 3.4e-06 s
# Forward: time: 0.866198s
# Interpolating to secondary mesh
#
# 512 	/ 512
# Forward: time: 1.31927s
# Response: min = 176.772 max = 197.192 mean = 190.394
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 29.0577/49.8991
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 635 x 451
# check Jacobian: wrong dimensions: (0x0) should be (327x451)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0015931:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.250571s
# sens sum: median = 0.976849 min = 0.67338 max = 1.02485
# ... 0.251148 s
# min data = 21.5055 max data = 3017.18 (327)
# min error = 0.0200404 max error = 0.0344142 (327)
# min response = 176.772 max response = 197.192 (327)
# calc without reference model
# 0: rms/rrms(data, response) = 287.413/63.2637%
# 0: chi^2(data, response, error, log) = 368.631
# 0: Phi = 120542 + 0 * 20 = 120542
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 2.89185 max = 36831.2
# Using existing primary potentials.
# Forward: time: 0.157089s
# Response: min = 46.7245 max = 614.909 mean = 160.982
# Reciprocity rms(modelReciprocity) 5.99771%, max: 32.5095%
# chi² = 202.08 (dPhi = 44.06%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: LS newModel: min = 2.89185; max = 36831.2
# 1: LS newResponse: min = 50.446; max = 620.055
# 1: rms/rrms(data, LS newResponse) = 256.444/38.7235%
# 1: chi^2(data, LS newResponse, error, log) = 388.309
# 1: Phi = 126977+333.406*20=133645
# Linesearch tau = 0.45
# Calculating response for model: min = 28.907 max = 2033.63
# Using existing primary potentials.
# Forward: time: 0.192914s
# Response: min = 105.405 max = 477.266 mean = 194.298
# Reciprocity rms(modelReciprocity) 2.66207%, max: 10.5751%
# 1: Model: min = 28.907; max = 2033.63
# 1: Response: min = 105.801; max = 478.261
# 1: rms/rrms(data, Response) = 260.052/46.7369%
# 1: chi^2(data, Response, error, log) = 202.076
# 1: Phi = 66078.9+67.5148*20=67429.2
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001989:time: 0.190112s
# sens sum: median = 1.39097 min = 1.0741 max = 2.43202
# ... 0.190622 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.45627 max = 11057.7
# Using existing primary potentials.
# Forward: time: 0.150322s
# Response: min = 45.7257 max = 485.818 mean = 183.089
# Reciprocity rms(modelReciprocity) 5.36902%, max: 22.026%
# 2: LS newModel: min = 3.45627; max = 11057.7
# 2: LS newResponse: min = 45.9442; max = 483.642
# 2: rms/rrms(data, LS newResponse) = 258.541/32.7624%
# 2: chi^2(data, LS newResponse, error, log) = 212.098
# 2: Phi = 69356.1+253.787*20=74431.9
# Linesearch tau = 0.34
# Calculating response for model: min = 14.1054 max = 2995.86
# Using existing primary potentials.
# Forward: time: 0.14637s
# Response: min = 80.1356 max = 524.813 mean = 195.43
# Reciprocity rms(modelReciprocity) 3.46068%, max: 12.8217%
# chi² = 179.04 (dPhi = 9.92%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 14.1054; max = 2995.86
# 2: Response: min = 80.7479; max = 524.213
# 2: rms/rrms(data, Response) = 255.039/41.4831%
# 2: chi^2(data, Response, error, log) = 179.038
# 2: Phi = 58545.4+109.654*20=60738.5
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0002009:time: 0.215246s
# sens sum: median = 1.75454 min = 1.12477 max = 4.48021
# ... 0.215743 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.59318 max = 6654.92
# Using existing primary potentials.
# Forward: time: 0.163305s
# Response: min = 47.0342 max = 583.79 mean = 196.62
# Reciprocity rms(modelReciprocity) 5.20489%, max: 22.5947%
# 3: LS newModel: min = 3.59318; max = 6654.92
# 3: LS newResponse: min = 49.5087; max = 605.127
# 3: rms/rrms(data, LS newResponse) = 247.364/35.6544%
# 3: chi^2(data, LS newResponse, error, log) = 159.747
# 3: Phi = 52237.4+219.881*20=56635
# Linesearch tau = 0.82
# Calculating response for model: min = 5.01098 max = 5398.45
# Using existing primary potentials.
# Forward: time: 0.150884s
# Response: min = 52.1862 max = 580.909 mean = 197.633
# Reciprocity rms(modelReciprocity) 4.866%, max: 20.552%
# chi² = 158.62 (dPhi = 8.18%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 5.01098; max = 5398.45
# 3: Response: min = 54.5311; max = 592.529
# 3: rms/rrms(data, Response) = 247.958/36.7467%
# 3: chi^2(data, Response, error, log) = 158.624
# 3: Phi = 51870+194.913*20=55768.3
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001968:time: 0.212314s
# chi² = 157.07 (dPhi = 1.51%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.51 (< 2.0%)                 #
# ################################################################################
# sens sum: median = 3.0149 min = 1.08025 max = 9.44799
# ... 0.212939 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 6.23341 max = 5337.22
# Using existing primary potentials.
# Forward: time: 0.145268s
# Response: min = 41.584 max = 553.889 mean = 196.683
# Reciprocity rms(modelReciprocity) 5.18345%, max: 19.461%
# 4: LS newModel: min = 6.23341; max = 5337.22
# 4: LS newResponse: min = 51.1413; max = 572.999
# 4: rms/rrms(data, LS newResponse) = 250.301/33.0539%
# 4: chi^2(data, LS newResponse, error, log) = 161.648
# 4: Phi = 52858.8+168.414*20=56227.1
# Linesearch tau = 0.4
# Calculating response for model: min = 5.46819 max = 5277.42
# Using existing primary potentials.
# Forward: time: 0.154773s
# Response: min = 50.1321 max = 575.884 mean = 198.312
# Reciprocity rms(modelReciprocity) 4.8596%, max: 20.3701%
# 4: Model: min = 5.46819; max = 5277.42
# 4: Response: min = 54.8251; max = 592.377
# 4: rms/rrms(data, Response) = 248.112/36.1453%
# 4: chi^2(data, Response, error, log) = 157.071
# 4: P
# 451 [128.0196266986385,...,151.03858538515414]
# hi = 51362.3+178.317*20=54928.6

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr3.showResult(**kw)
ax.grid(True)
ax.set_ylim([1532, ax.get_ylim()[1]])
# Out:
# (1532.0, 1575.122437)

# %% [markdown]
# Import dependencies

# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
from pygimli.physics import ert

# %% [markdown]
# Load ERT Data (Res2Dinv converted from FlashResZZ)

# %%
data = ert.load('Guapota_Res.dat')
print(data)
# Out:
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Data: Sensors: 32 data: 456, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %% [markdown]
# Show pseudosection

# %%
ax, cb = ert.show(data)

# %% [markdown]
# Compute geometric factors and do inversion

# %%
data["k"] = ert.geometricFactors(data)
data["err"] = ert.estimateError(data, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data, verbose=True)
mgr.invert()
# Out:
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - Found 2 regions.
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - Found 2 regions.
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 20/08/23 - 20:38:41 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 20/08/23 - 20:38:42 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1523 Cells: 2848 Boundaries: 2234
# 20/08/23 - 20:38:42 - pyGIMLi - INFO - Use median(data values)=179.74681091500003
# 20/08/23 - 20:38:42 - pyGIMLi - INFO - Created startmodel from forward operator: 492 [179.74681091500003,...,179.74681091500003]
# 20/08/23 - 20:38:42 - pyGIMLi - INFO - Starting inversion.
# ModellingBase::setMesh() copying new mesh ... Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 0.75, rMax = 93
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.00985012 s
# FOP updating mesh dependencies ... 4.198e-06 s
# min/max(dweight) = 40.1877/49.9887
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7fb9c830a6b0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7fb9c830a750>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7fb9c834c6d0>
# min/max (data): 10.61/2053
# min/max (error): 2%/2.49%
# min/max (start model): 180/180
# --------------------------------------------------------------------------------
# Calculating response for model: min = 179.747 max = 179.747
# Allocating memory for primary potential...... 0.00536059
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.41558s
# Response: min = 179.426 max = 179.776 mean = 179.636
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 40.1877/49.9887
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 695 x 492
# check Jacobian: wrong dimensions: (0x0) should be (456x492)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(12/12-std::mt): 0.00643815:--------------------------------------------------------------------------------time: 0.380072s
#
# inv.iter 1 ... sens sum: median = 0.957495 min = 0.668153 max = 1.01737
# ... 0.382384 s
# min data = 10.6082 max data = 2052.58 (456)
# min error = 0.0200045 max error = 0.0248832 (456)
# min response = 179.426 max response = 179.776 (456)
# calc without reference model
# 0: rms/rrms(data, response) = 122.476/109.531%
# 0: chi^2(data, response, error, log) = 510.445
# 0: Phi = 232763 + 0 * 20 = 232763
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = chi² = 201.02 (dPhi = 59.52%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 5.45866 max = 20368.5
# Using existing primary potentials.
# Forward: time: 0.312384s
# Response: min = 14.4417 max = 434.899 mean = 149.958
# Reciprocity rms(modelReciprocity) 3.70685%, max: 25.4438%
# 1: LS newModel: min = 5.45866; max = 20368.5
# 1: LS newResponse: min = 13.6732; max = 434.349
# 1: rms/rrms(data, LS newResponse) = 114.013/26.1011%
# 1: chi^2(data, LS newResponse, error, log) = 298.901
# 1: Phi = 136299+283.554*20=141970
# Linesearch tau = 0.67
# Calculating response for model: min = 17.2936 max = 4276.03
# Using existing primary potentials.
# Forward: time: 0.293095s
# Response: min = 36.0615 max = 388.045 mean = 162.953
# Reciprocity rms(modelReciprocity) 1.06057%, max: 9.25248%
# 1: Model: min = 17.2936; max = 4276.03
# 1: Response: min = 35.9039; max = 388.168
# 1: rms/rrms(data, Response) = 110.231/31.858%
# 1: chi^2(data, Response, error, log) = 201.023
# 1: Phi = 91666.5+127.288*20=94212.3
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(12/12-std::mt): 0.000378034:time: 0.398283s
# sens sum: median = 1.20896 min = 0.909673 max = 2.05272
# ... 0.399605 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 4.70404 max = 6709.73
# Using existing primary potentials.
# Forward: time: 0.303343s
# Response: min = 34.149 max = 577.976 mean = 173.661
# Reciprocity rms(modelReciprocity) 0.807798%, max: 4.73488%
# chi² = 127.5 (dPhi = 35.44%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: LS newModel: min = 4.70404; max = 6709.73
# 2: LS newResponse: min = 33.8422; max = 582.063
# 2: rms/rrms(data, LS newResponse) = 101.305/52.3424%
# 2: chi^2(data, LS newResponse, error, log) = 169.005
# 2: Phi = 77066.1+172.822*20=80522.5
# Linesearch tau = 0.63
# Calculating response for model: min = 7.61508 max = 5298.2
# Using existing primary potentials.
# Forward: time: 0.296102s
# Response: min = 52.8284 max = 454.147 mean = 171.097
# Reciprocity rms(modelReciprocity) 0.658013%, max: 3.32321%
# 2: Model: min = 7.61508; max = 5298.2
# 2: Response: min = 52.2903; max = 454.602
# 2: rms/rrms(data, Response) = 101.598/31.7619%
# 2: chi^2(data, Response, error, log) = 127.497
# 2: Phi = 58138.8+134.142*20=60821.6
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(12/12-std::mt): 0.000474709:time: 0.445064s
# chi² = 89.85 (dPhi = 26.7%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... sens sum: median = 1.48539 min = 0.983619 max = 2.6071
# ... 0.446335 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 8.39765 max = 16914.3
# Using existing primary potentials.
# Forward: time: 0.296741s
# Response: min = 21.5326 max = 563.932 mean = 176.747
# Reciprocity rms(modelReciprocity) 3.78008%, max: 37.6386%
# Linesearch tau = 1
# 3: Model: min = 8.39765; max = 16914.3
# 3: Response: min = 18.2008; max = 569.183
# 3: rms/rrms(data, Response) = 97.8226/16.6897%
# 3: chi^2(data, Response, error, log) = 89.8502
# 3: Phi = 40971.7+180.535*20=44582.4
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(12/12-std::mt): 0.000584399:time: 0.356839s
# sens sum: median = 1.51499 min = 0.611809 max = 3.74022
# ... 0.358211 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 6.69305 max = 5656.53
# Using existing primary potentials.
# Forward: time: 0.287134s
# Response: min = 53.0935 max = 513.026 mean = 180.863
# Reciprocity rms(modelReciprocity) 1.74899%, max: 15.6311%
# 4: LS newModel: min = 6.69305; max = 5656.53
# 4: LS newResponse: min = 49.4962; max = 519.471
# 4: rms/rrms(data, LS newResponse) = 100.488/30.0805%
# 4: chi^2(data, LS newResponse, error, log) = 114.135
# 4: Phi = 52045.6+171.954*20=55484.7
# Linesearch tau = 0.1
# chi² = 88.4 (dPhi = 1.7%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.7 (< 2.0%)                  #
# ################################################################################
# Calculating response for model: min = 8.36568 max = 12489
# Using existing primary potentials.
# Forward: time: 0.307659s
# Response: min = 22.1841 max = 573.328 mean = 177.412
# Reciprocity rms(modelReciprocity) 3.47464%, max: 34.766%
# 4: Model: min = 8.36568; max = 12489
# 4: Response: min = 19.3429; max = 578.888
# 4: rms/rrms(data, Response) = 97.6249/16.6614%
# 4: chi^2(data, Response, error, log) = 88.3979
# 4: Phi = 40309.4+175.764*20=43824.7
# 492 [1482.4342134285923,...,162.95333994374957]

# %% [markdown]
# Define colormap and plot inversion

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)")
ax, cb = mgr.showResult(**kw)
ax.grid(True)

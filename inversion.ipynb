# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
from pygimli.physics import ert

# %% [markdown]
# # November 24 ERT 1

# %%
data1 = ert.load('Surveys/nov24_pygimli.dat')
print(data1)
# Out:
# Data: Sensors: 57 data: 498, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data1)

# %%
data1["k"] = ert.geometricFactors(data1)
data1["err"] = ert.estimateError(data1, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data1, verbose=True,sr=False)

# %%
mgr.invert(lam=30, verbose=True)
# Out:
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2332 Cells: 4364 Boundaries: 3422
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Use median(data values)=95.514701845
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Created startmodel from forward operator: 850 [95.514701845,...,95.514701845]
# 28/11/23 - 22:38:46 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  1
#
# Statistics:
#
#   Input vertices: 121
#   Input segments: 122
#   Input holes: 0
#
#   Mesh vertices: 621
#   Mesh triangles: 1091
#   Mesh edges: 1711
#   Mesh exterior boundary edges: 149
#   Mesh interior boundary edges: 25
#   Mesh subsegments (constrained edges): 174
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1530.27 : 1530.16
# Found datafile: 57 electrodes
# Found: 57 node-electrodes
# rMin = 1.51017, rMax = 382.049
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.0109058 s
# FOP updating mesh dependencies ... 2.1e-06 s
# min/max(dweight) = 3.46953/49.9815
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e89fc3ab0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e89fc1440>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7e89fc09a0>
# min/max (data): 3.03/3804
# min/max (error): 2%/28.82%
# min/max (start model): 95.51/95.51
# --------------------------------------------------------------------------------
# Calculating response for model: min = 95.5147 max = 95.5147
# Forward: time: 0.35072s
# Response: min = 91.6062 max = 97.6456 mean = 95.2759
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 3.46953/49.9815
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1204 x 850
# check Jacobian: wrong dimensions: (0x0) should be (498x850)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0027686:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.885045s
# sens sum: median = 0.989062 min = 0.813291 max = 1.01588
# ... 0.886595 s
# min data = 3.02794 max data = 3803.68 (498)
# min error = 0.0200074 max error = 0.288223 (498)
# min response = 91.6062 max response = 97.6456 (498)
# calc without reference model
# 0: rms/rrms(data, response) = 373.595/296.282%
# 0: chi^2(data, response, error, log) = 2391.44
# 0: Phi = 1.19094e+06 + 0 * 30 = 1.19094e+06
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.130028 max = 6.04369e+06
# Forward: time: 0.372462s
# Response: min = 0.652477 max = 4598.03 mean = 83.6258
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 1817.63 (dPhi = 23.73%) lam: 30
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: LS newModel: min = 0.130028; max = 6.04369e+06
# 1: LS newResponse: min = 0.652477; max = 4598.03
# 1: rms/rrms(data, LS newResponse) = 401.363/131.462%
# 1: chi^2(data, LS newResponse, error, log) = 4407.43
# 1: Phi = 2.1949e+06+2131.89*30=2.25885e+06
# Linesearch tau = 0.22
# Calculating response for model: min = 22.3636 max = 1087.28
# Forward: time: 0.357101s
# Response: min = 59.8813 max = 190.009 mean = 98.0564
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 1: Model: min = 22.3636; max = 1087.28
# 1: Response: min = 59.8813; max = 190.009
# 1: rms/rrms(data, Response) = 361.797/278.736%
# 1: chi^2(data, Response, error, log) = 1817.63
# 1: Phi = 905182+103.184*30=908277
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0006269:time: 0.738399s
# sens sum: median = 1.1605 min = 0.743825 max = 1.59617
# ... 0.739664 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.190831 max = 150916
# Forward: time: 0.352503s
# Response: min = 4.88543 max = 988.033 mean = 93.8738
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 2: LS newModel: min = 0.190831; max = 150916
# 2: LS newResponse: min = 4.88543; max = 988.033
# 2: rms/rrms(data, LS newResponse) = 338.286/133.674%
# 2: chi^2(data, LS newResponse, error, log) = 2205.95
# 2: Phi = 1.09856e+06+1696.54*30=1.14946e+06
# Linesearch tau = 0.34
# Calculating response for model: min = 4.4271 max = 5817.76
# Forward: time: 0.340633s
# Response: min = 37.2729 max = 341.981 mean = 102.229
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 1326.12 (dPhi = 25.94%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 4.4271; max = 5817.76
# 2: Response: min = 37.2729; max = 341.981
# 2: rms/rrms(data, Response) = 344.74/257.856%
# 2: chi^2(data, Response, error, log) = 1326.12
# 2: Phi = 660406+408.286*30=672655
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004768:time: 0.657131s
# sens sum: median = 2.00284 min = 1.08265 max = 4.60293
# ... 0.658469 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.182541 max = 573689
# chi² = 972.76 (dPhi = 22.74%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Forward: time: 0.355178s
# Response: min = 15.0345 max = 964.177 mean = 116.063
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 3: LS newModel: min = 0.182541; max = 573689
# 3: LS newResponse: min = 15.0345; max = 964.177
# 3: rms/rrms(data, LS newResponse) = 316.421/228.319%
# 3: chi^2(data, LS newResponse, error, log) = 1071.56
# 3: Phi = 533635+1555.31*30=580294
# Linesearch tau = 0.75
# Calculating response for model: min = 0.405089 max = 135533
# Forward: time: 0.348125s
# Response: min = 20.9706 max = 759.513 mean = 117.336
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 3: Model: min = 0.405089; max = 135533
# 3: Response: min = 20.9706; max = 759.513
# 3: rms/rrms(data, Response) = 316.859/263.803%
# 3: chi^2(data, Response, error, log) = 972.761
# 3: Phi = 484435+1174.6*30=519673
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004907:time: 0.646213s
# sens sum: median = 4.70502 min = 0.919367 max = 84.3432
# ... 0.647544 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.334847 max = 129922
# Forward: time: 0.344816s
# Response: min = 14.9673 max = 1074.12 mean = 133.962
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 862.84 (dPhi = 10.39%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... Linesearch tau = 1
# 4: Model: min = 0.334847; max = 129922
# 4: Response: min = 14.9673; max = 1074.12
# 4: rms/rrms(data, Response) = 303.747/343.435%
# 4: chi^2(data, Response, error, log) = 862.843
# 4: Phi = 429696+1199.89*30=465693
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0010119:time: 0.785957s
# sens sum: median = 3.71428 min = -20.3587 max = 141.687
# ... 0.787191 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.672457 max = 226675
# Forward: time: 0.350071s
# Response: min = 3.90264 max = 994.112 mean = 92.2064
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.412755 max = 153532
# Forward: time: 0.384788s
# Response: min = 15.3398 max = 1094.53 mean = 130.54
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.159863
# chi² = 842.12 (dPhi = 2.66%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... 5: LS newModel: min = 0.672457; max = 226675
# 5: LS newResponse: min = 3.90264; max = 994.112
# 5: rms/rrms(data, LS newResponse) = 345.467/147.382%
# 5: chi^2(data, LS newResponse, error, log) = 1710.18
# 5: Phi = 851670+1286.66*30=890270
# Linesearch tau = 0.159863
# Calculating response for model: min = 0.374331 max = 142012
# Forward: time: 0.34875s
# Response: min = 15.0564 max = 1089.15 mean = 134.353
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 5: Model: min = 0.374331; max = 142012
# 5: Response: min = 15.0564; max = 1089.15
# 5: rms/rrms(data, Response) = 302.55/329.387%
# 5: chi^2(data, Response, error, log) = 842.119
# 5: Phi = 419375+1130.77*30=453298
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0005101:time: 0.860638s
# chi² = 821.96 (dPhi = 2.26%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... sens sum: median = 4.02749 min = -11.3738 max = 122.612
# ... 0.861935 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.376982 max = 336143
# Forward: time: 0.404808s
# Response: min = 8.52202 max = 1117.22 mean = 109.373
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.375124 max = 151824
# Forward: time: 0.343058s
# Response: min = 15.14 max = 1111.13 mean = 134.308
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.188111
# 6: LS newModel: min = 0.376982; max = 336143
# 6: LS newResponse: min = 8.52202; max = 1117.22
# 6: rms/rrms(data, LS newResponse) = 326.92/182.636%
# 6: chi^2(data, LS newResponse, error, log) = 1183.8
# 6: Phi = 589533+1376.81*30=630838
# Linesearch tau = 0.188111
# Calculating response for model: min = 0.374828 max = 148088
# Forward: time: 0.347266s
# Response: min = 15.0752 max = 1104.17 mean = 135.77
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 6: Model: min = 0.374828; max = 148088
# 6: Response: min = 15.0752; max = 1104.17
# 6: rms/rrms(data, Response) = 300.779/321.827%
# 6: chi^2(data, Response, error, log) = 821.963
# 6: Phi = 409337+1124.43*30=443070
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0008747:time: 0.775811s
# sens sum: median = 4.44911 min = -7.06184 max = 123.653
# ... 0.777052 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.232338 max = 396444
# Forward: time: 0.356315s
# Response: min = 15.261 max = 1154.4 mean = 140.696
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 7: LS newModel: min = 0.232338; max = 396444
# 7: LS newResponse: min = 15.261; max = 1154.4
# 7: rms/rrms(data, LS newResponse) = 297.068/318.38%
# 7: chi^2(data, LS newResponse, error, log) = 794.617
# 7: Phi = 395719+1392.53*30=437495
# Linesearch tau = 0.8
# Calculating response for model: min = 0.25566 max = 171574
# chi² = 780.7 (dPhi = 3.32%) lam: 30.0Forward: time: 0.35415s
# Response: min = 15.152 max = 1147.57 mean = 142.618
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 7: Model: min = 0.25566; max = 171574
# 7: Response: min = 15.152; max = 1147.57
# 7: rms/rrms(data, Response) = 295.159/331.783%
# 7: chi^2(data, Response, error, log) = 780.703
# 7: Phi = 388790+1318.43*30=428343
#
# --------------------------------------------------------------------------------
# inv.iter 8 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000535:time: 0.755649s
# sens sum: median = 5.7134 min = -18.699 max = 226.563
# ... 0.756845 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.44723 max = 150593
# Forward: time: 0.404977s
# Response: min = 13.1215 max = 1131.05 mean = 114.68
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.302359 max = 164990chi² = 761.12 (dPhi = 2.85%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 9 ...
# Forward: time: 0.41024s
# Response: min = 14.8815 max = 1145.11 mean = 146.961
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.227314
# 8: LS newModel: min = 0.44723; max = 150593
# 8: LS newResponse: min = 13.1215; max = 1131.05
# 8: rms/rrms(data, LS newResponse) = 325.525/241.707%
# 8: chi^2(data, LS newResponse, error, log) = 1107.97
# 8: Phi = 551767+1167.05*30=586779
# Linesearch tau = 0.227314
# Calculating response for model: min = 0.290315 max = 166562
# Forward: time: 0.382505s
# Response: min = 14.9499 max = 1145.9 mean = 146.598
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 8: Model: min = 0.290315; max = 166562
# 8: Response: min = 14.9499; max = 1145.9
# 8: rms/rrms(data, Response) = 291.889/352.263%
# 8: chi^2(data, Response, error, log) = 761.116
# 8: Phi = 379036+1237.09*30=416148
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004646:time: 0.783304s
# chi² = 727.44 (dPhi = 4.23%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... sens sum: median = 5.30457 min = -15.191 max = 192.966
# ... 0.784573 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.214609 max = 183502
# Forward: time: 0.348143s
# Response: min = 14.3133 max = 1339.76 mean = 166.116
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# Linesearch tau = 1
# 9: Model: min = 0.214609; max = 183502
# 9: Response: min = 14.3133; max = 1339.76
# 9: rms/rrms(data, Response) = 280.115/477.281%
# 9: chi^2(data, Response, error, log) = 727.437
# 9: Phi = 362263+1209.04*30=398535
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004529:time: 0.715499s
# sens sum: median = 5.09238 min = -45.9216 max = 312.747
# ... 0.71669 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.273586 max = 292015
# Forward: time: 0.352113s
# Response: min = 8.61722 max = 1155.77 mean = 122.822
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.230824 max = 182504
# Forward: time: 0.342153s
# Response: min = 14.2426 max = 1206.14 mean = 158.431
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.140725
# 10: LS newModel: min = 0.273586; max = 292015
# 10: LS newResponse: min = 8.61722; max = 1155.77
# 10: rms/rrms(data, LS newResponse) = 313.205/231.053%
# 10: chi^2(data, LS newResponse, error, log) = 965.509
# 10: Phi = 480823+1366.15*30=521808
# Linesearch tau = 0.140725
# Calculating response for model: min = 0.222068 max = 183033
# Forward: time: 0.359068s
# Response: min = 14.2771 max = 1299.34 mean = 163.841
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 724.83 (dPhi = 0.38%) lam: 30.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 0.38 (< 2.0%)                 #
# ################################################################################
# 10: Model: min = 0.222068; max = 183033
# 10: Response: min = 14.2771; max = 1299.34
# 10: rms/rrms(data, Response) = 280.805/455.468%
# 10: chi^2(data, Response, error, log) = 724.828
# 10: Phi = 360964+
# 850 [1624.2335929762378,...,3808.3250454158974]
# 1201.81*30=397019

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=50000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([1479, ax.get_ylim()[1]])
# Out:
# (1479.0, 1537.517944)

# %% [markdown]
# ## ...

# %% [markdown]
# # November 25 ERT 1

# %%
data2 = ert.load('Surveys/nov25_1_pygimli.dat')
print(data2)
# Out:
# Data: Sensors: 55 data: 671, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data2)
# Out:
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: divide by zero encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: invalid value encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:337: RuntimeWarning: invalid value encountered in subtract
#   ab, am, an = np.abs(a-b), np.abs(a-m), np.abs(a-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:338: RuntimeWarning: invalid value encountered in subtract
#   bm, bn, mn = np.abs(b-m), np.abs(b-n), np.abs(m-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:345: RuntimeWarning: invalid value encountered in subtract
#   sep = np.abs(a-m)  # * mI # does not make sense here
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:414: RuntimeWarning: invalid value encountered in multiply
#   mid *= de
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 28/11/23 - 22:39:04 - pyGIMLi - WARNING - Something gone wrong while drawing data. Try fallback with equidistant electrodes.

# %%
data2["k"] = ert.geometricFactors(data2)
data2["err"] = ert.estimateError(data2, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data2, verbose=True)
mgr.invert(lam=30, verbose=True)
# Out:
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2110 Cells: 3932 Boundaries: 3092
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Use median(data values)=53.19634628
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Created startmodel from forward operator: 773 [53.19634628,...,53.19634628]
# 28/11/23 - 22:39:05 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  1
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  1
#
# Statistics:
#
#   Input vertices: 117
#   Input segments: 118
#   Input holes: 0
#
#   Mesh vertices: 564
#   Mesh triangles: 983
#   Mesh edges: 1546
#   Mesh exterior boundary edges: 143
#   Mesh interior boundary edges: 24
#   Mesh subsegments (constrained edges): 167
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1461.69 : 1472.52
# Found datafile: 55 electrodes
# Found: 55 node-electrodes
# rMin = 1.25854, rMax = 320.05
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.010263 s
# FOP updating mesh dependencies ... 2e-06 s
# min/max(dweight) = 7.26825/49.9738
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e8a1a5bc0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7eb2914a40>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7e98dbe890>
# min/max (data): 2.84/1.6e+04
# min/max (error): 2%/13.76%
# min/max (start model): 53.2/53.2
# --------------------------------------------------------------------------------
# Calculating response for model: min = 53.1963 max = 53.1963
# Allocating memory for primary potential...... 0.0011191
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 8151	Cells: 3932	Boundaries: 6041
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1461.69 : 1472.52
# Found datafile: 55 electrodes
# Found: 55 node-electrodes
# rMin = 1.25854, rMax = 320.05
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.0154159 s
# FOP updating mesh dependencies ... 1.8e-06 s
# Forward: time: 4.82188s
# Interpolating to secondary mesh
#
# 990 	/ 990
# Forward: time: 6.12144s
# Response: min = 50.0573 max = 55.0212 mean = 53.2522
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 7.26825/49.9738
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1090 x 773
# check Jacobian: wrong dimensions: (0x0) should be (671x773)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0130134:--------------------------------------------------------------------------------time: 0.906243s
#
# inv.iter 1 ... sens sum: median = 0.991581 min = 0.666919 max = 1.02642
# ... 0.907812 s
# min data = 2.8439 max data = 15966.4 (671)
# min error = 0.0200105 max error = 0.137585 (671)
# min response = 50.0573 max response = 55.0212 (671)
# calc without reference model
# 0: rms/rrms(data, response) = 885.087/157.016%
# 0: chi^2(data, response, error, log) = 4307.15
# 0: Phi = 2.8901e+06 + 0 * 30 = 2.8901e+06
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.0188916 max = 1.18972e+08
# Using existing primary potentials.
# Forward: time: 0.311632s
# Found neg. resp (saving).
# 17 -410.447 488.709
# 17 20 18 19
# Response: min = -410.447 max = 1982.95 mean = 52.4896
# Reciprocity rms(modelReciprocity) 886.234%, max: 9972.26%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 4.90906 max = 4273.18
# Using existing primary potentials.
# Forward: time: 0.298188s
# Response: min = 21.1662 max = 151.137 mean = 53.862
# Reciprocity rms(modelReciprocity) 3.35864%, max: 46.7307%
#  ==> tau = 0.2269
# 1: LS newModel: min = 0.0188916; max = 1.18972e+08
# 1: LS newResponse: min = 0.316658; max = 1999.17
# 1: rms/rrms(data, LS newResponse) = 881.778/105.522%
# 1: chi^2(data, LS newchi² = 3485.29 (dPhi = 18.87%) lam: 30
# --------------------------------------------------------------------------------
# inv.iter 2 ... Response, error, log) = 13641.5
# 1: Phi = 9.15347e+06+3875.43*30=9.26973e+06
# Linesearch tau = 0.2269
# Calculating response for model: min = 8.77334 max = 1467.57
# Using existing primary potentials.
# Forward: time: 0.295844s
# Response: min = 29.2269 max = 117.275 mean = 55.5039
# Reciprocity rms(modelReciprocity) 2.23799%, max: 23.4531%
# 1: Model: min = 8.77334; max = 1467.57
# 1: Response: min = 28.9955; max = 116.112
# 1: rms/rrms(data, Response) = 881/132.556%
# 1: chi^2(data, Response, error, log) = 3485.29
# 1: Phi = 2.33863e+06+199.521*30=2.34462e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000609:time: 0.809936s
# sens sum: median = 1.42478 min = 0.692516 max = 2.40933
# ... 0.811369 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.118361 max = 1.0151e+08
# Using existing primary potentials.
# Forward: time: 0.305666s
# Found neg. resp (saving).
# 5 -2.93373 360.343
# 5 8 6 7
# Response: min = -2784.37 max = 4559.13 mean = 71.1705
# Reciprocity rms(modelReciprocity) 400.918%, max: 4084.3%
# 2: LS newModel: min = 0.118361; max = 1.0151e+08
# 2: LS newResponse: min = 0.501564; max = 4542.57
# 2: rms/rrms(data, LS newResponse) = 864.443/106.737%
# 2: chi^2(data, LS newResponse, error, log) = 5003.39
# 2: Phi = 3.35727e+06+3300.89*30=3.4563e+06
# Linesearch tau = 0.13
# chi² = 3071.02 (dPhi = 11.64%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Calculating response for model: min = 5.8226 max = 4114.52
# Using existing primary potentials.
# Forward: time: 0.307244s
# Response: min = 25.8798 max = 174.844 mean = 59.8376
# Reciprocity rms(modelReciprocity) 3.36881%, max: 43.4717%
# 2: Model: min = 5.8226; max = 4114.52
# 2: Response: min = 25.6124; max = 173.277
# 2: rms/rrms(data, Response) = 877.961/132.939%
# 2: chi^2(data, Response, error, log) = 3071.02
# 2: Phi = 2.06065e+06+371.689*30=2.0718e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0005852:time: 0.82231s
# sens sum: median = 1.8631 min = 0.745337 max = 3.66689
# ... 0.823809 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.280519 max = 1.81424e+07
# Using existing primary potentials.
# Forward: time: 0.311829s
# Found neg. resp (saving).
# 16 -322.59 -461.413
# 16 19 17 18
# Response: min = -4805.11 max = 3227.55 mean = 57.4051
# Reciprocity rms(modelReciprocity) 1351.11%, max: 31936.6%
# chi² = 2512.15 (dPhi = 17.44%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: LS newModel: min = 0.280519; max = 1.81424e+07
# 3: LS newResponse: min = 1.95702; max = 3223.02
# 3: rms/rrms(data, LS newResponse) = 859.905/111.72%
# 3: chi^2(data, LS newResponse, error, log) = 3614.69
# 3: Phi = 2.42546e+06+3113.72*30=2.51887e+06
# Linesearch tau = 0.28
# Calculating response for model: min = 3.26416 max = 34439.1
# Using existing primary potentials.
# Forward: time: 0.296041s
# Response: min = 19.3444 max = 382.241 mean = 67.6141
# Reciprocity rms(modelReciprocity) 6.96738%, max: 84.9158%
# 3: Model: min = 3.26416; max = 34439.1
# 3: Response: min = 19.3287; max = 380.351
# 3: rms/rrms(data, Response) = 871.559/131.698%
# 3: chi^2(data, Response, error, log) = 2512.15
# 3: Phi = 1.68565e+06+825.228*30=1.71041e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000688:time: 0.789447s
# sens sum: median = 2.79607 min = 0.795125 max = 6.02885
# ... 0.790824 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.727434 max = 3.53716e+07
# Using existing primary potentials.
# Forward: time: 0.315941s
# Found neg. resp (saving).
# 16 -1159.94 129.12
# 16 19 17 18
# Response: min = chi² = 1954.82 (dPhi = 21.32%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... -17787.1 max = 15530 mean = 78.8923
# Reciprocity rms(modelReciprocity) 757.327%, max: 4180.57%
# 4: LS newModel: min = 0.727434; max = 3.53716e+07
# 4: LS newResponse: min = 1.95471; max = 12883.1
# 4: rms/rrms(data, LS newResponse) = 1105.04/304.927%
# 4: chi^2(data, LS newResponse, error, log) = 2882.85
# 4: Phi = 1.93439e+06+2475.68*30=2.00867e+06
# Linesearch tau = 0.35
# Calculating response for model: min = 2.92586 max = 92757.3
# Using existing primary potentials.
# Forward: time: 0.30929s
# Response: min = 7.94313 max = 726.836 mean = 84.9933
# Reciprocity rms(modelReciprocity) 16.7301%, max: 101.459%
# 4: Model: min = 2.92586; max = 92757.3
# 4: Response: min = 13.4839; max = 726.128
# 4: rms/rrms(data, Response) = 860.853/150.771%
# 4: chi^2(data, Response, error, log) = 1954.82
# 4: Phi = 1.31169e+06+1135.1*30=1.34574e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0009174:time: 0.879926s
# sens sum: median = 3.09699 min = 0.692254 max = 8.10739
# ... 0.881806 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 0.307067 max = 2.10742e+06
# Using existing primary potentials.
# Forward: time: 0.291931s
# Found neg. resp (saving).
# 17 -936.142 704.752
# 17 20 18 19
# Response: min = -3351.26 max = 2458.14 mean = 89.759
# Reciprocity rms(modelReciprocity) 771.874%, max: 2265.52%
# 5: LS newModel: min = 0.307067; max = 2.10742e+06
# 5: LS newResponse: min = 2.07077; max = 2456.82
# 5: rms/rrms(data, LS newResponse) = 841.643/234.279%
# 5: chi^2(data, LS newResponse, error, log) = 2115.69
# 5: Phi = 1.41963e+06+2576.3*30=1.49692e+06
# Linesearch tau = 0.35
# Calculating response for model: min = 1.9381 max = 276751
# Using existing primary potentials.
# Forward: time: 0.309596s
# Response: min = 14.6358 max = 1124.54 mean = 100.374
# Reciprocity rms(modelReciprocity) 20.1926%, max: 131.98%
# 5: Model: min = 1.9381; max = 276751
# 5: Response: min = 12.101; max = 1125.19
# 5: rms/rrms(data, Response) = 851.121/174.848%
# 5: chi^2(data, Response, error, log) = 1694.83
# 5: Phi = 1.13723e+06+1423.08*30=1.17992e+06
# chi² = 1694.83 (dPhi = 12.32%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0005381:time: 0.762973s
# sens sum: median = 3.93013 min = 0.724305 max = 18.1454
# ... 0.764404 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 1.26184 max = 1.44699e+06
# Using existing primary potentials.
# Forward: time: 0.296353s
# Found neg. resp (saving).
# 18 -1164.76 2714.15
# 18 21 19 20
# Response: min = -1164.76 max = 2694.33 mean = 123.044
# Reciprocity rms(modelReciprocity) 160.991%, max: 2957.41%
# 6: LS newModel: min = 1.26184; max = 1.44699e+06
# 6: LS newResponse: min = 1.74039; max = 2666.37
# 6: rms/rrms(data, LS newResponse) = 849.689/209.218%
# 6: chi^2(data, LS newResponse, error, log) = 2036.58
# 6: Phi = 1.36655e+06+2173.6*30=1.43175e+06
# Linesearch tau = 0.18
# Calculating response for model: min = 2.05507 max = 360619
# Using existing primary potentials.
# Forward: time: 0.323429s
# Response: min = 15.5149 max = 1314.36 mean = 108.954
# Reciprocity rms(modelReciprocity) 21.8753%, max: 119.831%
# chi² = 1596.17 (dPhi = 5.49%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... 6: Model: min = 2.05507; max = 360619
# 6: Response: min = 12.1595; max = 1316.11
# 6: rms/rrms(data, Response) = 846.222/185.675%
# 6: chi^2(data, Response, error, log) = 1596.17
# 6: Phi = 1.07103e+06+1471.69*30=1.11518e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004984:time: 0.916587s
# sens sum: median = 3.81732 min = 0.717447 max = 16.556
# ... 0.918043 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 1.11467 max = 2.56146e+06
# Using existing primary potentials.
# Forward: time: 0.319681s
# Found neg. resp (saving).
# 17 -4219.39 11832.6
# 17 20 18 19
# Response: min = -24053.1 max = 9561.06 mean = 110.17
# Reciprocity rms(modelReciprocity) 1390.54%, max: 29651.6%
# 7: LS newModel: min = 1.11467; max = 2.56146e+06
# 7: LS newResponse: min = 5.40623; max = 17035.7
# 7: rms/rrms(data, LS newResponse) = 1209.2/370.684%
# 7: chi^2(data, LS newResponse, error, log) = 2192.54
# 7: Phi = 1.47119e+06+2252.25*30=1.53876e+06
# Linesearch tau = 0.07
# Calculating response for model: min = 1.99683 max = 381858
# Using existing primary potentials.
# Forward: time: 0.319262s
# Response: min = 13.6865 max = 1383.83 mean = 112.443
# Reciprocity rms(modelReciprocity) 22.6047%, max: 127.608%
# chi² = 1568.37 (dPhi = 1.6%) lam: 30.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.6 (< 2.0%)                  #
# ################################################################################
# 7: Model: min = 1.99683; max = 381858
# 7: Response: min = 12.2087; max = 1385.87
# 7: rms/rrms(data, Response) = 844.401/189.412%
# 7: chi^2(data, Response, error, log) = 1568.37
# 7: Phi = 1.05238e+06+
# 773 [1193.3814399339806,...,891.2811229862631]
# 1499.17*30=1.09735e+06

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=50000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([1441, ax.get_ylim()[1]])
# Out:
# (1441.0, 1490.006104)

# %% [markdown]
# # ...

# %% [markdown]
# # November 25 ERT 2

# %%
data3 = ert.load('Surveys/nov25_2_pygimli.dat')
print(data3)
# Out:
# Data: Sensors: 32 data: 327, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data3)

# %%
data3["k"] = ert.geometricFactors(data3)
data3["err"] = ert.estimateError(data3, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data3, verbose=True)
mgr.invert(lam=30, verbose=True)
# Out:
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Found 2 regions.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1325 Cells: 2456 Boundaries: 1938
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Use median(data values)=190.12710571
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Created startmodel from forward operator: 451 [190.12710571,...,190.12710571]
# 28/11/23 - 22:39:23 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 71
#   Input segments: 72
#   Input holes: 0
#
#   Mesh vertices: 356
#   Mesh triangles: 614
#   Mesh edges: 969
#   Mesh exterior boundary edges: 96
#   Mesh interior boundary edges: 16
#   Mesh subsegments (constrained edges): 112
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0063986 s
# FOP updating mesh dependencies ... 1.9e-06 s
# min/max(dweight) = 29.0577/49.8991
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e8a2add00>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e98d8ca40>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7e8a2af9c0>
# min/max (data): 21.51/3017
# min/max (error): 2%/3.44%
# min/max (start model): 190/190
# --------------------------------------------------------------------------------
# Calculating response for model: min = 190.127 max = 190.127
# Allocating memory for primary potential...... 0.000306
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 5105	Cells: 2456	Boundaries: 3780
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0077657 s
# FOP updating mesh dependencies ... 1.9e-06 s
# Forward: time: 0.78369s
# Interpolating to secondary mesh
#
# 512 	/ 512
# Forward: time: 1.18422s
# Response: min = 176.772 max = 197.192 mean = 190.394
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 29.0577/49.8991
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 635 x 451
# check Jacobian: wrong dimensions: (0x0) should be (327x451)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0014876:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.183308s
# sens sum: median = 0.976849 min = 0.67338 max = 1.02485
# ... 0.183859 s
# min data = 21.5055 max data = 3017.18 (327)
# min error = 0.0200404 max error = 0.0344142 (327)
# min response = 176.772 max response = 197.192 (327)
# calc without reference model
# 0: rms/rrms(data, response) = 287.413/63.2637%
# 0: chi^2(data, response, error, log) = 368.631
# 0: Phi = 120542 + 0 * 30 = 120542
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 5.37943 max = 19550
# Using existing primary potentials.
# Forward: time: 0.147726s
# Response: min = 55.6764 max = 662.875 mean = 172.991
# Reciprocity rms(modelReciprocity) 5.2802%, max: 21.7443%
# 1: LS newModel: min = 5.37943; max = 19550
# 1: LS newResponse: min = 58.5537; max = 666.868
# 1: rms/rrms(data, LS newResponse) = 250.172/37.7074%
# 1: chi^2(data, LS newResponse, error, log) = 296.625
# 1: Phi = 96996.5+chi² = 192.45 (dPhi = 45.83%) lam: 30234.25*30=104024
# Linesearch tau = 0.58
# Calculating response for model: min = 24.045 max = 2792.95
# Using existing primary potentials.
# Forward: time: 0.181281s
# Response: min = 91.7385 max = 535.279 mean = 193.882
# Reciprocity rms(modelReciprocity) 2.99614%, max: 11.2867%
# 1: Model: min = 24.045; max = 2792.95
# 1: Response: min = 92.0464; max = 536.287
# 1: rms/rrms(data, Response) = 255.281/44.0305%
# 1: chi^2(data, Response, error, log) = 192.446
# 1: Phi = 62930+78.8018*30=65294
#
# --------------------------------------------------------------------------------
# inv.iter 2 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0002609:time: 0.278636s
# sens sum: median = 1.51904 min = 1.09298 max = 3.25356
# ... 0.279247 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 7.77756 max = 4206.36
# Using existing primary potentials.
# Forward: time: 0.145935s
# Response: min = 52.9546 max = 472.18 mean = 186.47
# Reciprocity rms(modelReciprocity) 4.28188%, max: 15.4837%
# 2: LS newModel: min = 7.77756; max = 4206.36
# 2: LS newResponse: min = 53.9378; max = 479.643
# 2: rms/rrms(data, LS newResponse) = 258.222/32.86%
# 2: chi^2(data, LS newResponse, error, log) = 184.82
# 2: Phi = 60436.1+148.754*30=64898.7
# Linesearch tau = 0.52
# Calculating response for model: min = 14.0941 max = 2415.68
# Using existing primary potentials.
# Forward: time: 0.148678s
# Response: min = 69.2088 max = 529.98 mean = 193.435
# Reciprocity rms(modelReciprocity) 3.63441%, max: 12.6963%
# chi² = 174.57 (dPhi = 7.77%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 14.0941; max = 2415.68
# 2: Response: min = 70.144; max = 528.743
# 2: rms/rrms(data, Response) = 254.016/38.4178%
# 2: chi^2(data, Response, error, log) = 174.572
# 2: Phi = 57085+104.527*30=60220.8
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0002003:time: 0.21451s
# chi² = 156.59 (dPhi = 7.64%) lam: 30.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... sens sum: median = 1.74435 min = 1.08778 max = 4.18825
# ... 0.215084 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 7.44335 max = 4224.89
# Using existing primary potentials.
# Forward: time: 0.15164s
# Response: min = 53.3056 max = 623.624 mean = 204.047
# Reciprocity rms(modelReciprocity) 4.52664%, max: 19.0111%
# Linesearch tau = 1
# 3: Model: min = 7.44335; max = 4224.89
# 3: Response: min = 56.1821; max = 644.194
# 3: rms/rrms(data, Response) = 244.264/38.7084%
# 3: chi^2(data, Response, error, log) = 156.595
# 3: Phi = 51206.5+147.167*30=55621.5
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001968:time: 0.189252s
# chi² = 156.78 (dPhi = 0.13%) lam: 30.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 0.13 (< 2.0%)                 #
# ################################################################################
# sens sum: median = 2.25934 min = 1.02554 max = 5.67149
# ... 0.18974 s
# solve CGLSCDWWtrans with lambda = 30
# Calculating response for model: min = 10.2414 max = 4092.06
# Using existing primary potentials.
# Forward: time: 0.153542s
# Response: min = 47.7662 max = 537.508 mean = 197.021
# Reciprocity rms(modelReciprocity) 4.69861%, max: 17.104%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 8.19116 max = 4111.83
# Using existing primary potentials.
# Forward: time: 0.144122s
# Response: min = 52.5005 max = 602.228 mean = 202.661
# Reciprocity rms(modelReciprocity) 4.52328%, max: 18.4409%
#  ==> tau = 0.178089
# 4: LS newModel: min = 10.2414; max = 4092.06
# 4: LS newResponse: min = 55.8743; max = 555.942
# 4: rms/rrms(data, LS newResponse) = 251.373/34.82%
# 4: chi^2(data, LS newResponse, error, log) = 163.869
# 4: Phi = 53585.3+132.696*30=57566.2
# Linesearch tau = 0.178089
# Calculating response for model: min = 7.87861 max = 4115.29
# Using existing primary potentials.
# Forward: time: 0.147913s
# Response: min = 52.8984 max = 611.368 mean = 203.299
# Reciprocity rms(modelReciprocity) 4.52129%, max: 18.6727%
# 4: Model: min = 7.87861; max = 4115.29
# 4: Response: min = 56.4635; max = 631.797
# 4: rms/rrms(data, Response) = 245.224/38.3614%
# 4: chi^2(data, Response, error, log) = 156.783
# 4: Phi = 51268+142.687*30=55548.6
# 451 [123.85135155432604,...,166.04400983963822]

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=50000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([1532, ax.get_ylim()[1]])
# Out:
# (1532.0, 1575.122437)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
from pygimli.physics import ert

# %% [markdown]
# # November 24 ERT 1

# %%
data1 = ert.load('Surveys/nov24_pygimli.dat')
print(data1)
# Out:
# Data: Sensors: 57 data: 498, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data1)

# %%
data1["k"] = ert.geometricFactors(data1)
data1["err"] = ert.estimateError(data1, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data1, verbose=True,sr=False)

# %%
mgr.invert(verbose=True)
# Out:
# 29/11/23 - 01:55:45 - pyGIMLi - INFO - Use median(data values)=95.514701845
# 29/11/23 - 01:55:45 - pyGIMLi - INFO - Created startmodel from forward operator: 850 [95.514701845,...,95.514701845]
# 29/11/23 - 01:55:45 - pyGIMLi - INFO - Starting inversion.
# Found datafile: 57 electrodes
# Found: 57 node-electrodes
# Found non-Neumann domain
# min/max(dweight) = 3.46953/49.9815
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e8a285bc0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e8a325620>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7e8a3277e0>
# min/max (data): 3.03/3804
# min/max (error): 2%/28.82%
# min/max (start model): 95.51/95.51
# --------------------------------------------------------------------------------
# Calculating response for model: min = 95.5147 max = 95.5147
# Forward: time: 0.398696s
# Response: min = 91.6062 max = 97.6456 mean = 95.2759
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 3.46953/49.9815
#  found valid constraints matrix. omit rebuild
# constraint matrix of size(nBounds x nModel) 1204 x 850
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0007327:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.744189s
# sens sum: median = 0.989062 min = 0.813291 max = 1.01588
# ... 0.745358 s
# min data = 3.02794 max data = 3803.68 (498)
# min error = 0.0200074 max error = 0.288223 (498)
# min response = 91.6062 max response = 97.6456 (498)
# calc without reference model
# 0: rms/rrms(data, response) = 373.595/296.282%
# 0: chi^2(data, response, error, log) = 2391.44
# 0: Phi = 1.19094e+06 + 0 * 20 = 1.19094e+06
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.0376401 max = 1.61277e+07
# Forward: time: 0.354868s
# Response: min = 0.242116 max = 5216.08 mean = 75.5004
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 1: LS newModel: min = 0.0376401; max = 1.61277e+07
# 1: LS newResponse: min = 0.242116; max = 5216.08
# 1: rms/rrms(data, LS newResponse) = 424.67/106.621%
# 1: chi^2(data, LS newResponse, error, log) = 6080.92
# 1: Phi = 3.0283e+06+2966.47*20=3.08763e+06
# Linesearch tau = 0.14
# Calculating response for model: min = 31.8751 max = 515.134
# Forward: time: 0.361524s
# Response: min = 72.6262 max = 144.002 mean = 97.2973
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 1989.53 (dPhi = 16.71%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 31.8751; max = 515.134
# 1: Response: min = 72.6262; max = 144.002
# 1: rms/rrms(data, Response) = 366.077/283.557%
# 1: chi^2(data, Response, error, log) = 1989.53
# 1: Phi = 990788+58.1428*20=991951
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004662:time: 0.732271s
# sens sum: median = 1.07009 min = 0.789761 max = 1.30052
# ... 0.733701 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.0783772 max = 351486
# Forward: time: 0.38045s
# Response: min = 2.36715 max = 1279.32 mean = 89.0109
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 2: LS newModel: min = 0.0783772; max = 351486
# 2: LS newResponse: min = 2.36715; max = 1279.32
# 2: rms/rrms(data, LS newResponse) = 352.256/113.752%
# 2: chi^2(data, LS newResponse, error, log) = 3255.56
# 2: Phi = 1.62127e+06+2431.73*20=1.66991e+06
# Linesearch tau = 0.23
# chi² = 1533.41 (dPhi = 22.44%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Calculating response for model: min = 8.00426 max = 2310.67
# Forward: time: 0.393348s
# Response: min = 49.1256 max = 241.85 mean = 100.257
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 2: Model: min = 8.00426; max = 2310.67
# 2: Response: min = 49.1256; max = 241.85
# 2: rms/rrms(data, Response) = 353.434/267.956%
# 2: chi^2(data, Response, error, log) = 1533.41
# 2: Phi = 763638+286.485*20=769368
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0009711:time: 0.857533s
# sens sum: median = 1.57676 min = 1.04509 max = 2.74926
# ... 0.858752 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.108304 max = 589051
# Forward: time: 0.383635s
# Response: min = 7.84817 max = 1040.59 mean = 98.0421
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 3: LS newModel: min = 0.108304; max = 589051
# 3: LS newResponse: min = 7.84817; max = 1040.59
# 3: rms/rrms(data, LS newResponse) = 337.447/167.099%
# 3: chi^2(data, LS newResponse, error, log) = 1809.22
# 3: Phi = 900992+2038.59*20=941763
# Linesearch tau = 0.33
# Calculating response for model: min = 1.9349 max = 14383.2
# Forward: time: 0.359772s
# Response: min = 36.0364 max = 395.05 mean = 106.077
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 1183.45 (dPhi = 21.68%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 1.9349; max = 14383.2
# 3: Response: min = 36.0364; max = 395.05
# 3: rms/rrms(data, Response) = 338.078/271.621%
# 3: chi^2(data, Response, error, log) = 1183.45
# 3: Phi = 589359+660.445*20=602568
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004698:time: 0.669325s
# sens sum: median = 2.68901 min = 1.16202 max = 11.3281
# ... 0.670974 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.194984 max = 497310
# Forward: time: 0.346449s
# Response: min = 16.1085 max = 1109.27 mean = 132.877
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# Linesearch tau = 1
# 4: Model: min = 0.194984; max = 497310
# 4: Response: min = 16.1085; max = 1109.27
# 4: rms/rrms(data, Response) = 299.192/288.06%
# 4: chi^2(data, Response, error, log) = 852.343
# 4: Phi = 424467+1866.22*20=461791
# chi² = 852.34 (dPhi = 23.36%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004432:time: 0.664083s
# sens sum: median = 7.85433 min = -16.3798 max = 258.288
# ... 0.66527 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.32091 max = 343528
# Forward: time: 0.341283s
# Response: min = 7.14654 max = 1175.29 mean = 94.0002
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.22642 max = 386759
# Forward: time: 0.356544s
# Response: min = 16.1029 max = 1127.22 mean = 138.308
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.216144
# 5: LS newModel: min = 0.32091; max = 343528
# 5: LS newResponse: min = 7.14654; max = 1175.29
# 5: rms/rrms(data, LS newResponse) = 340.107/251.278%
# 5: chi^2(data, LS newResponse, error, log) = 1813.94
# 5: Phi = 903343+1131.56*20=925974
# Linesearch tau = 0.216144
# Calculating response for model: min = 0.217155 max = 392290
# Forward: time: 0.349178s
# Response: min = 16.193 max = 1121.88 mean = 137.885
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 806.14 (dPhi = 6.24%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... 5: Model: min = 0.217155; max = 392290
# 5: Response: min = 16.193; max = 1121.88
# 5: rms/rrms(data, Response) = 294.86/319.936%
# 5: chi^2(data, Response, error, log) = 806.142
# 5: Phi = 401459+1575.51*20=432969
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004516:time: 0.754292s
# sens sum: median = 6.34215 min = -16.6279 max = 237.1
# ... 0.755995 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.194799 max = 338054
# Forward: time: 0.363867s
# Response: min = 14.5079 max = 1309.38 mean = 153.661
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 6: LS newModel: min = chi² = 750.02 (dPhi = 7.62%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... 0.194799; max = 338054
# 6: LS newResponse: min = 14.5079; max = 1309.38
# 6: rms/rrms(data, LS newResponse) = 286.041/503.371%
# 6: chi^2(data, LS newResponse, error, log) = 762.354
# 6: Phi = 379652+1317.8*20=406008
# Linesearch tau = 0.9
# Calculating response for model: min = 0.196927 max = 343122
# Forward: time: 0.36628s
# Response: min = 14.6467 max = 1303.05 mean = 154.756
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# 6: Model: min = 0.196927; max = 343122
# 6: Response: min = 14.6467; max = 1303.05
# 6: rms/rrms(data, Response) = 284.877/489.003%
# 6: chi^2(data, Response, error, log) = 750.025
# 6: Phi = 373512+1323.47*20=399982
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004751:time: 0.751622s
# sens sum: median = 5.24347 min = -44.8056 max = 323.469
# ... 0.753015 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.103028 max = 789119
# Forward: time: 0.344284s
# Response: min = 8.77067 max = 1163.32 mean = 113.405
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 0.202508 max = 324381
# Forward: time: 0.352726s
# Response: min = 14.5114 max = 1181 mean = 148.779
# Reciprocity rms(modelReciprocity) 0%, max: 0%
#  ==> tau = 0.138566
# 7: LS newModel: min = 0.103028; max = 789119
# 7: LS newResponse: min = 8.77067; max = 1163.32
# 7: rms/rrms(data, LS newResponse) = 322.557/313.424%
# 7: chi^2(data, LS newResponse, error, log) = 1186.61
# 7: Phi = 590932+1854.83*20=628028
# Linesearch tau = 0.138566
# Calculating response for model: min = 0.199485 max = 334335
# Forward: time: 0.354822s
# Response: min = 14.5512 max = 1269.15 mean = 153.667
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# chi² = 742.43 (dPhi = 0.79%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 0.79 (< 2.0%)                 #
# ################################################################################
# 850 [1460.089558910327,...,3649.454499835212]
# 7: Model: min = 0.199485; max = 334335
# 7: Response: min = 14.5512; max = 1269.15
# 7: rms/rrms(data, Response) = 285.136/462.536%
# 7: chi^2(data, Response, error, log) = 742.431
# 7: Phi = 369730+1354.46*20=396820

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([1479, ax.get_ylim()[1]])
# Out:
# (1479.0, 1537.517944)

# %% [markdown]
# ## ...

# %% [markdown]
# # November 25 ERT 1

# %%
data2 = ert.load('Surveys/nov25_1_pygimli.dat')
print(data2)
# Out:
# Data: Sensors: 55 data: 671, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data2)
# Out:
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: divide by zero encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:289: RuntimeWarning: invalid value encountered in divide
#   ne = np.round(xe/de)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:337: RuntimeWarning: invalid value encountered in subtract
#   ab, am, an = np.abs(a-b), np.abs(a-m), np.abs(a-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:338: RuntimeWarning: invalid value encountered in subtract
#   bm, bn, mn = np.abs(b-m), np.abs(b-n), np.abs(m-n)
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:345: RuntimeWarning: invalid value encountered in subtract
#   sep = np.abs(a-m)  # * mI # does not make sense here
# /home/ubuntu_jc/anaconda3/envs/pg/lib/python3.10/site-packages/pygimli/physics/ert/visualization.py:414: RuntimeWarning: invalid value encountered in multiply
#   mid *= de
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu_jc/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 29/11/23 - 01:57:00 - pyGIMLi - WARNING - Something gone wrong while drawing data. Try fallback with equidistant electrodes.

# %%
data2["k"] = ert.geometricFactors(data2)
data2["err"] = ert.estimateError(data2, relativeError=0.02, absoluteUError=50e-6)
mgr2 = ert.ERTManager(data2, verbose=True)
mgr2.invert(verbose=True)
# Out:
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2110 Cells: 3932 Boundaries: 3092
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Use median(data values)=53.19634628
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Created startmodel from forward operator: 773 [53.19634628,...,53.19634628]
# 29/11/23 - 01:55:08 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 117
#   Input segments: 118
#   Input holes: 0
#
#   Mesh vertices: 564
#   Mesh triangles: 983
#   Mesh edges: 1546
#   Mesh exterior boundary edges: 143
#   Mesh interior boundary edges: 24
#   Mesh subsegments (constrained edges): 167
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1461.69 : 1472.52
# Found datafile: 55 electrodes
# Found: 55 node-electrodes
# rMin = 1.25854, rMax = 320.05
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.0099881 s
# FOP updating mesh dependencies ... 2.2e-06 s
# min/max(dweight) = 7.26825/49.9738
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e98d5dbc0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e98d30130>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7e99851210>
# min/max (data): 2.84/1.6e+04
# min/max (error): 2%/13.76%
# min/max (start model): 53.2/53.2
# --------------------------------------------------------------------------------
# Calculating response for model: min = 53.1963 max = 53.1963
# Allocating memory for primary potential...... 0.0010129
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 8151	Cells: 3932	Boundaries: 6041
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1461.69 : 1472.52
# Found datafile: 55 electrodes
# Found: 55 node-electrodes
# rMin = 1.25854, rMax = 320.05
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.0190344 s
# FOP updating mesh dependencies ... 1.9e-06 s
# Forward: time: 4.39442s
# Interpolating to secondary mesh
#
# 990 	/ 990
# Forward: time: 5.51579s
# Response: min = 50.0573 max = 55.0212 mean = 53.2522
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 7.26825/49.9738
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1090 x 773
# check Jacobian: wrong dimensions: (0x0) should be (671x773)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00269:--------------------------------------------------------------------------------time: 0.840183s
#
# inv.iter 1 ... sens sum: median = 0.991581 min = 0.666919 max = 1.02642
# ... 0.842071 s
# min data = 2.8439 max data = 15966.4 (671)
# min error = 0.0200105 max error = 0.137585 (671)
# min response = 50.0573 max response = 55.0212 (671)
# calc without reference model
# 0: rms/rrms(data, response) = 885.087/157.016%
# 0: chi^2(data, response, error, log) = 4307.15
# 0: Phi = 2.8901e+06 + 0 * 20 = 2.8901e+06
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.00713797 max = 3.51478e+08
# Using existing primary potentials.
# Forward: time: 0.316423s
# Found neg. resp (saving).
# 6 -42.7562 261.728
# 6 9 7 8
# Response: min = -1067 max = 2367.43 mean = 53.3156
# Reciprocity rms(modelReciprocity) 3227.19%, max: 30607.3%
# tau = 0. Trying parabolic line search with step length 0.3Calculating response for model: min = 3.66598 max = 5914.07
# Using existing primary potentials.
# Forward: time: 0.302517s
# Response: min = 18.5883 max = 166.867 mean = 52.1446
# Reciprocity rms(modelReciprocity) 3.72613%, max: 52.4341%
#  ==> tau = chi² = 3543.08 (dPhi = 17.58%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 0.208208
# 1: LS newModel: min = 0.00713797; max = 3.51478e+08
# 1: LS newResponse: min = 0.0712621; max = 2154.68
# 1: rms/rrms(data, LS newResponse) = 881.692/114.956%
# 1: chi^2(data, LS newResponse, error, log) = 15502.4
# 1: Phi = 1.04021e+07+5152.34*20=1.05052e+07
# Linesearch tau = 0.208208
# Calculating response for model: min = 8.3107 max = 1399.14
# Using existing primary potentials.
# Forward: time: 0.332718s
# Response: min = 29.2284 max = 115.883 mean = 54.8653
# Reciprocity rms(modelReciprocity) 2.19678%, max: 21.5417%
# 1: Model: min = 8.3107; max = 1399.14
# 1: Response: min = 28.9906; max = 114.733
# 1: rms/rrms(data, Response) = 881.278/133.389%
# 1: chi^2(data, Response, error, log) = 3543.08
# 1: Phi = 2.37741e+06+223.356*20=2.38187e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000497:time: 0.918581s
# sens sum: median = 1.45123 min = 0.823339 max = 2.341
# ... 0.920065 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.0253191 max = 9.09403e+08
# Using existing primary potentials.
# Forward: time: 0.325093s
# Found neg. resp (saving).
# 5 -372.014 340.244
# 5 8 6 7
# Response: min = -8766.85 max = 4908.19 mean = 48.703
# Reciprocity rms(modelReciprocity) 572.687%, max: 9310.43%
# tau = 0.02. Trying parabolic line search with step length 0.3Calculating response for model: min = 1.88904 max = 53079.2
# Using existing primary potentials.
# Forward: time: 0.300064s
# Response: min = 19.172 max = 326.652 mean = 61.1505
# Reciprocity rms(modelReciprocity) 7.66857%, max: 121.289%
#  ==> tau = 0.296677
# chi² = 2896.17 (dPhi = 17.69%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: LS newModel: min = 0.0253191; max = 9.09403e+08
# 2: LS newResponse: min = 0.637253; max = 4873.27
# 2: rms/rrms(data, LS newResponse) = 871.049/118.248%
# 2: chi^2(data, LS newResponse, error, log) = 6324.25
# 2: Phi = 4.24357e+06+4374.04*20=4.33106e+06
# Linesearch tau = 0.296677
# Calculating response for model: min = 1.92811 max = 50678.8
# Using existing primary potentials.
# Forward: time: 0.315404s
# Response: min = 19.3057 max = 322.527 mean = 61.1362
# Reciprocity rms(modelReciprocity) 7.53333%, max: 118.635%
# 2: Model: min = 1.92811; max = 50678.8
# 2: Response: min = 18.9918; max = 319.512
# 2: rms/rrms(data, Response) = 875.265/123.619%
# 2: chi^2(data, Response, error, log) = 2896.17
# 2: Phi = 1.94333e+06+863.743*20=1.96061e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0004922:time: 0.875727s
# sens sum: median = 3.04254 min = 0.893883 max = 6.18838
# ... 0.877584 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.597498 max = 5.17742e+07
# Using existing primary potentials.
# Forward: time: 0.319023s
# Found neg. resp (saving).
# 16 -1639.39 39.4131
# 16 19 17 18
# Response: min = -37761.3 max = 9866.52 mean = -35.1537
# Reciprocity rms(modelReciprocity) 1960.63%, max: 49431.1%
# 3: LS newModel: min = 0.597498; max = 5.17742e+07
# 3: LS newResponse: min = 1.7267; max = 4918.82
# 3: rms/rrms(data, LS newResponse) = 914.301/404.071%
# 3: chi^2(data, LS newResponse, error, log) = 3551.95
# 3: Phi = 2.38336e+06+3320.07*20=2.44976e+06
# Linesearch tau = 0.31
# Calculating response for model: min = 1.88373 max = 42380.6
# Using existing primary potentials.
# Forward: time: 0.298365s
# Response: min = 9.35589 max = 588.758 mean = 72.8094
# Reciprocity rms(modelReciprocity) 13.8717%, max: 118.177%
# chi² = 2293.74 (dPhi = 20.29%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 1.88373; max = 42380.6
# 3: Response: min = 14.8905; max = 586.378
# 3: rms/rrms(data, Response) = 867.002/141.989%
# 3: chi^2(data, Response, error, log) = 2293.74
# 3: Phi = 1.5391e+06+1188.24*20=1.56286e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0010317:time: 0.931944s
# sens sum: median = 3.40017 min = 0.745187 max = 8.14513
# ... 0.933522 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 0.435081 max = 1.01384e+07
# Using existing primary potentials.
# Forward: time: 0.332854s
# Found neg. resp (saving).
# 17 -1200.98 232.911
# 17 20 18 19
# Response: min = -5550.58 max = 2361.67 mean = 70.7957
# Reciprocity rms(modelReciprocity) 1086.5%, max: 26256.6%
# 4: LS newModel: min = 0.435081; max = 1.01384e+07
# 4: LS newResponse: min = 3.27793; max = 2888.59
# 4: rms/rrms(data, LS newResponse) = 856.739/230.78%
# 4: chi^2(data, LS newResponse, error, log) = 2705.77
# 4: Phi = 1.81557e+06+3291.56*20=1.8814e+06
# Linesearch tau = 0.24
# Calculating response for model: min = 1.87434 max = 121397
# Using existing primary potentials.
# Forward: time: 0.326125s
# Response: min = 16.0287 max = 838.402 mean = 83.4945
# Reciprocity rms(modelReciprocity) 15.9001%, max: 119.31%
# chi² = 1965.17 (dPhi = 13.8%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... 4: Model: min = 1.87434; max = 121397
# 4: Response: min = 14.2451; max = 837.408
# 4: rms/rrms(data, Response) = 859.956/155.33%
# 4: chi^2(data, Response, error, log) = 1965.17
# 4: Phi = 1.31863e+06+1428.96*20=1.34721e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0009706:time: 0.835946s
# sens sum: median = 3.94861 min = 0.806924 max = 10.5612
# ... 0.837789 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 1.09495 max = 8.32658e+06
# Using existing primary potentials.
# Forward: time: 0.299303s
# Found neg. resp (saving).
# 15 -453.945 550.604
# 15 18 16 17
# Response: min = -12799.7 max = 3656.2 mean = 73.3842
# Reciprocity rms(modelReciprocity) 620.931%, max: 9009.31%
# chi² = 1735.09 (dPhi = 11.22%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... 5: LS newModel: min = 1.09495; max = 8.32658e+06
# 5: LS newResponse: min = 1.83009; max = 3383.52
# 5: rms/rrms(data, LS newResponse) = 873.959/332.249%
# 5: chi^2(data, LS newResponse, error, log) = 2498.69
# 5: Phi = 1.67662e+06+2862.14*20=1.73387e+06
# Linesearch tau = 0.23
# Calculating response for model: min = 1.8744 max = 273270
# Using existing primary potentials.
# Forward: time: 0.320389s
# Response: min = 18.62 max = 1091.17 mean = 95.7543
# Reciprocity rms(modelReciprocity) 18.4202%, max: 121.163%
# 5: Model: min = 1.8744; max = 273270
# 5: Response: min = 14.3334; max = 1091.66
# 5: rms/rrms(data, Response) = 852.712/167.533%
# 5: chi^2(data, Response, error, log) = 1735.09
# 5: Phi = 1.16425e+06+1592.51*20=1.1961e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0007426:time: 0.861499s
# sens sum: median = 4.21685 min = 0.817024 max = 13.1205
# ... 0.862994 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 1.13261 max = 1.64696e+07
# Using existing primary potentials.
# Forward: time: 0.334033s
# Found neg. resp (saving).
# 15 -1117.81 981.714
# 15 18 16 17
# Response: min = -86540.2 max = 37902.1 mean = -43.3032
# Reciprocity rms(modelReciprocity) 11852.4%, max: 19652.4%
# 6: LS newModel: min = 1.13261; max = 1.64696e+07
# 6: LS newResponse: min = 6.37253; max = 35981.1
# 6: rms/rrms(data, LS newResponse) = 2461.48/982.895%
# 6: chi^2(data, LS newResponse, error, log) = 2909.09
# 6: Phi = 1.952e+06+2788.62*20=2.00777e+06
# Linesearch tau = 0.08
# Calculating response for model: min = 1.82485 max = 275420
# Using existing primary potentials.
# Forward: time: 0.320255s
# Response: min = 16.8021 max = 1174.22 mean = 100.38
# Reciprocity rms(modelReciprocity) 19.7544%, max: 121.969%
# chi² = 1678.51 (dPhi = 3.1%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... 6: Model: min = 1.82485; max = 275420
# 6: Response: min = 14.3409; max = 1174.96
# 6: rms/rrms(data, Response) = 850.226/172.574%
# 6: chi^2(data, Response, error, log) = 1678.51
# 6: Phi = 1.12628e+06+1638.37*20=1.15905e+06
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0006906:time: 0.905452s
# sens sum: median = 4.21954 min = 0.800762 max = 13.9894
# ... 0.906815 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 1.05699 max = 1.20451e+08
# Using existing primary potentials.
# Forward: time: 0.315044s
# Found neg. resp (saving).
# 15 -1566.78 1114.9
# 15 18 16 17
# Response: min = -234552 max = 30065.1 mean = -449.708
# Reciprocity rms(modelReciprocity) chi² = 1649.38 (dPhi = 1.64%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.64 (< 2.0%)                 #
# ################################################################################
# 773 [1128.0977251301235,...,614.5436720402313]
# 1843.77%, max: 18429.6%
# 7: LS newModel: min = 1.05699; max = 1.20451e+08
# 7: LS newResponse: min = 5.18849; max = 67931.9
# 7: rms/rrms(data, LS newResponse) = 4891.5/1579.55%
# 7: chi^2(data, LS newResponse, error, log) = 3197.65
# 7: Phi = 2.14562e+06+2773.31*20=2.20109e+06
# Linesearch tau = 0.05
# Calculating response for model: min = 1.81294 max = 279437
# Using existing primary potentials.
# Forward: time: 0.310103s
# Response: min = 14.8232 max = 1225.42 mean = 103.455
# Reciprocity rms(modelReciprocity) 20.7573%, max: 123.35%
# 7: Model: min = 1.81294; max = 279437
# 7: Response: min = 14.3423; max = 1226.34
# 7: rms/rrms(data, Response) = 848.725/175.658%
# 7: chi^2(data, Response, error, log) = 1649.38
# 7: Phi = 1.10674e+06+1663.78*20=1.14001e+06

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr2.showResult(**kw)
ax.grid(True)
ax.set_ylim([1441, ax.get_ylim()[1]])
# Out:
# (1441.0, 1490.006104)

# %% [markdown]
# # ...

# %% [markdown]
# # November 25 ERT 2

# %%
data3 = ert.load('Surveys/nov25_2_pygimli.dat')
print(data3)
# Out:
# Data: Sensors: 32 data: 327, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data3)

# %%
data3["k"] = ert.geometricFactors(data3)
data3["err"] = ert.estimateError(data3, relativeError=0.02, absoluteUError=50e-6)
mgr3 = ert.ERTManager(data3, verbose=True)
mgr3.invert(verbose=True)
# Out:
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Found 2 regions.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1325 Cells: 2456 Boundaries: 1938
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Use median(data values)=190.12710571
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Created startmodel from forward operator: 451 [190.12710571,...,190.12710571]
# 29/11/23 - 01:56:27 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 71
#   Input segments: 72
#   Input holes: 0
#
#   Mesh vertices: 356
#   Mesh triangles: 614
#   Mesh edges: 969
#   Mesh exterior boundary edges: 96
#   Mesh interior boundary edges: 16
#   Mesh subsegments (constrained edges): 112
#
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0077392 s
# FOP updating mesh dependencies ... 2.9e-06 s
# min/max(dweight) = 29.0577/49.8991
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f7e98a91030>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f7e98af0c70>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x7f7eb2c56070>
# min/max (data): 21.51/3017
# min/max (error): 2%/3.44%
# min/max (start model): 190/190
# --------------------------------------------------------------------------------
# Calculating response for model: min = 190.127 max = 190.127
# Allocating memory for primary potential...... 0.0006105
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 5105	Cells: 2456	Boundaries: 3780
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=1571.83 : 1571.73
# Found datafile: 32 electrodes
# Found: 32 node-electrodes
# rMin = 2.50062, rMax = 311.107
# NGauLeg + NGauLag for inverse Fouriertransformation: 12 + 4
# Found non-Neumann domain
# 0.0109201 s
# FOP updating mesh dependencies ... 3.4e-06 s
# Forward: time: 0.866198s
# Interpolating to secondary mesh
#
# 512 	/ 512
# Forward: time: 1.31927s
# Response: min = 176.772 max = 197.192 mean = 190.394
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 29.0577/49.8991
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 635 x 451
# check Jacobian: wrong dimensions: (0x0) should be (327x451)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0015931:--------------------------------------------------------------------------------
# inv.iter 1 ... time: 0.250571s
# sens sum: median = 0.976849 min = 0.67338 max = 1.02485
# ... 0.251148 s
# min data = 21.5055 max data = 3017.18 (327)
# min error = 0.0200404 max error = 0.0344142 (327)
# min response = 176.772 max response = 197.192 (327)
# calc without reference model
# 0: rms/rrms(data, response) = 287.413/63.2637%
# 0: chi^2(data, response, error, log) = 368.631
# 0: Phi = 120542 + 0 * 20 = 120542
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 2.89185 max = 36831.2
# Using existing primary potentials.
# Forward: time: 0.157089s
# Response: min = 46.7245 max = 614.909 mean = 160.982
# Reciprocity rms(modelReciprocity) 5.99771%, max: 32.5095%
# chi² = 202.08 (dPhi = 44.06%) lam: 20
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: LS newModel: min = 2.89185; max = 36831.2
# 1: LS newResponse: min = 50.446; max = 620.055
# 1: rms/rrms(data, LS newResponse) = 256.444/38.7235%
# 1: chi^2(data, LS newResponse, error, log) = 388.309
# 1: Phi = 126977+333.406*20=133645
# Linesearch tau = 0.45
# Calculating response for model: min = 28.907 max = 2033.63
# Using existing primary potentials.
# Forward: time: 0.192914s
# Response: min = 105.405 max = 477.266 mean = 194.298
# Reciprocity rms(modelReciprocity) 2.66207%, max: 10.5751%
# 1: Model: min = 28.907; max = 2033.63
# 1: Response: min = 105.801; max = 478.261
# 1: rms/rrms(data, Response) = 260.052/46.7369%
# 1: chi^2(data, Response, error, log) = 202.076
# 1: Phi = 66078.9+67.5148*20=67429.2
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001989:time: 0.190112s
# sens sum: median = 1.39097 min = 1.0741 max = 2.43202
# ... 0.190622 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.45627 max = 11057.7
# Using existing primary potentials.
# Forward: time: 0.150322s
# Response: min = 45.7257 max = 485.818 mean = 183.089
# Reciprocity rms(modelReciprocity) 5.36902%, max: 22.026%
# 2: LS newModel: min = 3.45627; max = 11057.7
# 2: LS newResponse: min = 45.9442; max = 483.642
# 2: rms/rrms(data, LS newResponse) = 258.541/32.7624%
# 2: chi^2(data, LS newResponse, error, log) = 212.098
# 2: Phi = 69356.1+253.787*20=74431.9
# Linesearch tau = 0.34
# Calculating response for model: min = 14.1054 max = 2995.86
# Using existing primary potentials.
# Forward: time: 0.14637s
# Response: min = 80.1356 max = 524.813 mean = 195.43
# Reciprocity rms(modelReciprocity) 3.46068%, max: 12.8217%
# chi² = 179.04 (dPhi = 9.92%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 14.1054; max = 2995.86
# 2: Response: min = 80.7479; max = 524.213
# 2: rms/rrms(data, Response) = 255.039/41.4831%
# 2: chi^2(data, Response, error, log) = 179.038
# 2: Phi = 58545.4+109.654*20=60738.5
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0002009:time: 0.215246s
# sens sum: median = 1.75454 min = 1.12477 max = 4.48021
# ... 0.215743 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.59318 max = 6654.92
# Using existing primary potentials.
# Forward: time: 0.163305s
# Response: min = 47.0342 max = 583.79 mean = 196.62
# Reciprocity rms(modelReciprocity) 5.20489%, max: 22.5947%
# 3: LS newModel: min = 3.59318; max = 6654.92
# 3: LS newResponse: min = 49.5087; max = 605.127
# 3: rms/rrms(data, LS newResponse) = 247.364/35.6544%
# 3: chi^2(data, LS newResponse, error, log) = 159.747
# 3: Phi = 52237.4+219.881*20=56635
# Linesearch tau = 0.82
# Calculating response for model: min = 5.01098 max = 5398.45
# Using existing primary potentials.
# Forward: time: 0.150884s
# Response: min = 52.1862 max = 580.909 mean = 197.633
# Reciprocity rms(modelReciprocity) 4.866%, max: 20.552%
# chi² = 158.62 (dPhi = 8.18%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 5.01098; max = 5398.45
# 3: Response: min = 54.5311; max = 592.529
# 3: rms/rrms(data, Response) = 247.958/36.7467%
# 3: chi^2(data, Response, error, log) = 158.624
# 3: Phi = 51870+194.913*20=55768.3
# calculating jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0001968:time: 0.212314s
# chi² = 157.07 (dPhi = 1.51%) lam: 20.0
# ################################################################################
# #                 Abort criteria reached: dPhi = 1.51 (< 2.0%)                 #
# ################################################################################
# sens sum: median = 3.0149 min = 1.08025 max = 9.44799
# ... 0.212939 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 6.23341 max = 5337.22
# Using existing primary potentials.
# Forward: time: 0.145268s
# Response: min = 41.584 max = 553.889 mean = 196.683
# Reciprocity rms(modelReciprocity) 5.18345%, max: 19.461%
# 4: LS newModel: min = 6.23341; max = 5337.22
# 4: LS newResponse: min = 51.1413; max = 572.999
# 4: rms/rrms(data, LS newResponse) = 250.301/33.0539%
# 4: chi^2(data, LS newResponse, error, log) = 161.648
# 4: Phi = 52858.8+168.414*20=56227.1
# Linesearch tau = 0.4
# Calculating response for model: min = 5.46819 max = 5277.42
# Using existing primary potentials.
# Forward: time: 0.154773s
# Response: min = 50.1321 max = 575.884 mean = 198.312
# Reciprocity rms(modelReciprocity) 4.8596%, max: 20.3701%
# 4: Model: min = 5.46819; max = 5277.42
# 4: Response: min = 54.8251; max = 592.377
# 4: rms/rrms(data, Response) = 248.112/36.1453%
# 4: chi^2(data, Response, error, log) = 157.071
# 4: P
# 451 [128.0196266986385,...,151.03858538515414]
# hi = 51362.3+178.317*20=54928.6

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr3.showResult(**kw)
ax.grid(True)
ax.set_ylim([1532, ax.get_ylim()[1]])
# Out:
# (1532.0, 1575.122437)

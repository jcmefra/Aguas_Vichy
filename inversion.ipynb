# %%
import matplotlib.pyplot as plt
import numpy as np
import pygimli as pg
from pygimli.physics import ert

# %% [markdown]
# # November 24 ERT 1

# %%
data = ert.load('Surveys/No_Topo_Nov24.dat')
print(data)
# Out:
# 25/11/23 - 18:02:59 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Data: Sensors: 57 data: 498, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data)

# %%
data["k"] = ert.geometricFactors(data)
data["err"] = ert.estimateError(data, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data, verbose=True)
mgr.invert(lam=30, verbose=True)
# Out:
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2446 Cells: 4588 Boundaries: 3592
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Use median(data values)=95.514701845
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Created startmodel from forward operator: 880 [95.514701845,...,95.514701845]
# 25/11/23 - 18:03:00 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# ...

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([-40, ax.get_ylim()[1]])
# Out:
# (-40.0, 0.0)

# %% [markdown]
# ## ...

# %% [markdown]
# # November 25 ERT 1

# %%
data = ert.load('Surveys/No_Topo_Nov25_1.dat')
print(data)
# Out:
# 25/11/23 - 18:03:14 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Data: Sensors: 55 data: 671, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data)

# %%
data["k"] = ert.geometricFactors(data)
data["err"] = ert.estimateError(data, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data, verbose=True)
mgr.invert(lam=30, verbose=True)
# Out:
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2263 Cells: 4232 Boundaries: 3320
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Use median(data values)=53.19634628
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Created startmodel from forward operator: 799 [53.19634628,...,53.19634628]
# 25/11/23 - 18:03:15 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# ...

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([-40, ax.get_ylim()[1]])
# Out:
# (-40.0, 0.0)

# %% [markdown]
# # ...

# %% [markdown]
# # November 25 ERT 2

# %%
data = ert.load('Surveys/No_Topo_Nov25_2.dat')
print(data)
# Out:
# 25/11/23 - 18:03:44 - pyGIMLi - INFO - could not read unified data format for ERT ... try res2dinv
# Data: Sensors: 32 data: 327, nonzero entries: ['a', 'b', 'm', 'n', 'rhoa', 'valid']

# %%
ax, cb = ert.show(data)

# %%
data["k"] = ert.geometricFactors(data)
data["err"] = ert.estimateError(data, relativeError=0.02, absoluteUError=50e-6)
mgr = ert.ERTManager(data, verbose=True)
mgr.invert(lam=30, verbose=True)
# Out:
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Found 2 regions.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1411 Cells: 2640 Boundaries: 2070
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Use median(data values)=190.12710571
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Created startmodel from forward operator: 493 [190.12710571,...,190.12710571]
# 25/11/23 - 18:03:45 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# ...

# %%
kw = dict(logScale=True, cMap="Spectral_r", xlabel="x (m)", ylabel="y (m)", cMin=0, cMax=100000)
ax, cb = mgr.showResult(**kw)
ax.grid(True)
ax.set_ylim([-40, ax.get_ylim()[1]])
# Out:
# (-40.0, 0.0)
